# %%
# ============================================================
# Cell 1. 安裝套件、掛載 Google Drive、設定環境與路徑
# ============================================================

# !pip install -q transformers scikit-learn pandas tqdm

import os
import json
import random
import warnings
import numpy as np
import pandas as pd
import torch

from tqdm import tqdm
from google.colab import drive

warnings.filterwarnings("ignore")

# ============================================================
# 1.1 掛載 Google Drive
# ============================================================

if not os.path.exists("/content/drive/MyDrive"):
    drive.mount("/content/drive")
else:
    print("✅ Google Drive 已經掛載，不需要重新掛載。")

# ============================================================
# 1.2 固定 Random Seed
# ============================================================

SEED = 42

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(SEED)

# ============================================================
# 1.3 設定裝置
# ============================================================

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("使用裝置：", device)

if torch.cuda.is_available():
    print("GPU 名稱：", torch.cuda.get_device_name(0))
else:
    print("⚠️ 目前沒有偵測到 GPU，請確認 Colab 已開啟硬體加速器。")

# ============================================================
# 1.4 設定資料夾與檔案路徑
# ============================================================

PROJECT_DIR = "/content/drive/MyDrive/ESG_Project"
MODEL_DIR = "/content/drive/MyDrive/ESG_Models"

os.makedirs(PROJECT_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)

RAW_DATA_PATH = "/content/vpesg4k_train_1000.json"

DATA_URL = "https://raw.githubusercontent.com/veripromiseesg/veripromiseesgdataset/ac91c1c8b5d116edf6fc44cccc1ee3b618f5a207/vpesg4ktrain1000v1.json"

SAVE_MODEL_PATH = os.path.join(MODEL_DIR, "best_single_roberta_task13.pt")
SAVE_SPLIT_PATH = os.path.join(PROJECT_DIR, "task13_train_valid_test_split.json")
SAVE_HISTORY_PATH = os.path.join(PROJECT_DIR, "task13_training_history.json")

# ============================================================
# 1.5 如果資料不存在，就下載官方訓練資料
# ============================================================

if not os.path.exists(RAW_DATA_PATH):
    print("找不到資料，開始下載...")
    # !wget -q -O /content/vpesg4k_train_1000.json {DATA_URL}
    print("✅ 資料下載完成")
else:
    print("✅ 資料已存在，不需要重新下載")

# ============================================================
# 1.6 檢查資料是否真的存在
# ============================================================

if os.path.exists(RAW_DATA_PATH):
    print("✅ 已確認資料檔存在")
else:
    raise FileNotFoundError(f"找不到資料檔：{RAW_DATA_PATH}")

print("\n路徑設定完成：")
print("PROJECT_DIR       =", PROJECT_DIR)
print("MODEL_DIR         =", MODEL_DIR)
print("RAW_DATA_PATH     =", RAW_DATA_PATH)
print("SAVE_MODEL_PATH   =", SAVE_MODEL_PATH)
print("SAVE_SPLIT_PATH   =", SAVE_SPLIT_PATH)
print("SAVE_HISTORY_PATH =", SAVE_HISTORY_PATH)
# Out:
# Mounted at /content/drive
# 使用裝置： cuda
# GPU 名稱： Tesla T4
# 找不到資料，開始下載...
# ✅ 資料下載完成
# ✅ 已確認資料檔存在
#
# 路徑設定完成：
# PROJECT_DIR       = /content/drive/MyDrive/ESG_Project
# MODEL_DIR         = /content/drive/MyDrive/ESG_Models
# RAW_DATA_PATH     = /content/vpesg4k_train_1000.json
# SAVE_MODEL_PATH   = /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt
# SAVE_SPLIT_PATH   = /content/drive/MyDrive/ESG_Project/task13_train_valid_test_split.json
# SAVE_HISTORY_PATH = /content/drive/MyDrive/ESG_Project/task13_training_history.json

# %%
# ============================================================
# Cell 2. 讀取原始資料與檢查欄位
# ============================================================

# 讀取官方 1000 筆訓練資料
with open(RAW_DATA_PATH, "r", encoding="utf-8") as f:
    raw_data = json.load(f)

print("原始資料型態：", type(raw_data))
print("原始資料筆數：", len(raw_data))

# 檢查第一筆資料
print("\n第一筆資料 keys：")
print(list(raw_data[0].keys()))

print("\n第一筆資料完整內容：")
print(json.dumps(raw_data[0], ensure_ascii=False, indent=2)[:2000])

# ============================================================
# 2.1 檢查必要欄位是否存在
# ============================================================

REQUIRED_COLUMNS = [
    "id",
    "data",
    "promise_status",
    "promise_string",
    "verification_timeline",
    "evidence_status",
    "evidence_string",
    "evidence_quality"
]

missing_cols = []

for col in REQUIRED_COLUMNS:
    if col not in raw_data[0]:
        missing_cols.append(col)

if len(missing_cols) == 0:
    print("\n✅ 必要欄位都存在")
else:
    print("\n⚠️ 缺少欄位：", missing_cols)

# ============================================================
# 2.2 快速查看幾筆文字與標籤
# ============================================================

print("\n前 3 筆資料摘要：")

for i in range(3):
    item = raw_data[i]
    print("\n" + "=" * 80)
    print("index:", i)
    print("id:", item.get("id"))
    print("data:", str(item.get("data", ""))[:300])
    print("promise_status:", item.get("promise_status"))
    print("promise_string:", item.get("promise_string"))
    print("verification_timeline:", item.get("verification_timeline"))
    print("evidence_status:", item.get("evidence_status"))
    print("evidence_string:", item.get("evidence_string"))
    print("evidence_quality:", item.get("evidence_quality"))
# Out:
# 原始資料型態： <class 'list'>
# 原始資料筆數： 1000
#
# 第一筆資料 keys：
# ['id', 'data', 'esg_type', 'promise_status', 'promise_string', 'verification_timeline', 'evidence_status', 'evidence_string', 'evidence_quality', 'company', 'ticker', 'page_number', 'pdf_url', 'company_source']
#
# 第一筆資料完整內容：
# {
#   "id": 10001,
#   "data": "聯發科技除在「工作規則」中依照勞基法明確規定「員工在產假期間公司不得終止勞動契約」外，為支持同仁與其家人度過人生不同階段，自 2024 年起提供女性員工在分娩前後計有 12 週共 84 天的產假；男性員工則可於其配偶懷孕期間陪同產檢或生（流）產日及前後 15 日間請假陪伴，兩者合計共有 10 天陪產（檢）假可運用，陪產（檢）假期間工資照常給付。",
#   "esg_type": "S",
#   "promise_status": "Yes",
#   "promise_string": "為支持同仁與其家人度過人生不同階段，自 2024 年起提供女性員工在分娩前後計有 12 週共 84 天的產假；男性員工則可於其配偶懷孕期間陪同產檢或生（流）產日及前後 15 日間請假陪伴，兩者合計共有 10 天陪產（檢）假可運用，陪產（檢）假期間工資照常給付。",
#   "verification_timeline": "already",
#   "evidence_status": "No",
#   "evidence_string": "",
#   "evidence_quality": "N/A",
#   "company": "mediatek",
#   "ticker": 2454,
#   "page_number": 48,
#   "pdf_url": "https://hsxn1sjvkgtdpixe.public.blob.vercel-storage.com/mediatek_2454_page_48.pdf",
#   "company_source": "https://corp.mediatek.tw/about/sustainability"
# }
#
# ✅ 必要欄位都存在
#
# 前 3 筆資料摘要：
#
# ================================================================================
# index: 0
# id: 10001
# data: 聯發科技除在「工作規則」中依照勞基法明確規定「員工在產假期間公司不得終止勞動契約」外，為支持同仁與其家人度過人生不同階段，自 2024 年起提供女性員工在分娩前後計有 12 週共 84 天的產假；男性員工則可於其配偶懷孕期間陪同產檢或生（流）產日及前後 15 日間請假陪伴，兩者合計共有 10 天陪產（檢）假可運用，陪產（檢）假期間工資照常給付。
# promise_status: Yes
# promise_string: 為支持同仁與其家人度過人生不同階段，自 2024 年起提供女性員工在分娩前後計有 12 週共 84 天的產假；男性員工則可於其配偶懷孕期間陪同產檢或生（流）產日及前後 15 日間請假陪伴，兩者合計共有 10 天陪產（檢）假可運用，陪產（檢）假期間工資照常給付。
# verification_timeline: already
# evidence_status: No
# evidence_string:
# evidence_quality: N/A
#
# ================================================================================
# index: 1
# id: 10002
# data: 在與供應商攜手邁向永續發展的過程中，台泥致力於建立一套以合作為基礎的價值體體系。核心原則是推動供應鏈的低碳轉型，同時維護人權、保護環境和促進生物多樣性，以建立永續的合作夥伴關係。
# promise_status: Yes
# promise_string: 台泥致力於建立一套以合作為基礎的價值體體系。
# verification_timeline: between_2_and_5_years
# evidence_status: Yes
# evidence_string: 核心原則是推動供應鏈的低碳轉型，同時維護人權、保護環境和促進生物多樣性，以建立永續的合作夥伴關係。
# evidence_quality: Not Clear
#
# ================================================================================
# index: 2
# id: 10003
# data: III. 產品危害物質減免 (HSF) 短、中、長期目標設定    **1. 2024 年 目標和實績**  *   已達標  *   詳述於 "產品各階段危害物質減免風險管理目標與成效"    **2. 短期目標 2025~2026 年**  *   監控 PFAS 中有害物質管制要求  *   減少 RoHS 豁免零件之使用，往 Lead Free 持續前進。    **3. 中長期目標 2026~2027 年**  *   優化綠色管理系統審查作業提升效率。
# promise_status: Yes
# promise_string: III. 產品危害物質減免 (HSF) 短、中、長期目標設定
# verification_timeline: between_2_and_5_years
# evidence_status: Yes
# evidence_string: 1. 2024 年 目標和實績**  *   已達標  *   詳述於 "產品各階段危害物質減免風險管理目標與成效"    **2. 短期目標 2025~2026 年**  *   監控 PFAS 中有害物質管制要求  *   減少 RoHS 豁免零件之使用，往 Lead Free 持續前進。    **3. 中長期目標 2026~2027 年**  *   優化綠色管理系統審查作業提升效率。
# evidence_quality: Not Clear

# %%
# ============================================================
# Cell 3. 定義官方權重、任務欄位、標籤與文字輸入格式
# ============================================================

# ============================================================
# 3.1 官方評分權重
# ============================================================

OFFICIAL_WEIGHTS = {
    "promise_status": 0.20,
    "evidence_status": 0.30,
    "evidence_quality": 0.35,
    "verification_timeline": 0.15
}

print("官方評分權重：")
for field, weight in OFFICIAL_WEIGHTS.items():
    print(f"{field}: {weight}")

# ============================================================
# 3.2 這次 RoBERTa 只訓練任務 1 與任務 3
# ============================================================

TASK_FIELDS = [
    "promise_status",
    "evidence_status"
]

LABEL_LISTS = {
    "promise_status": ["Yes", "No"],
    "evidence_status": ["Yes", "No", "N/A"]
}

label2id = {
    field: {label: i for i, label in enumerate(labels)}
    for field, labels in LABEL_LISTS.items()
}

id2label = {
    field: {i: label for i, label in enumerate(labels)}
    for field, labels in LABEL_LISTS.items()
}

num_labels_dict = {
    field: len(labels)
    for field, labels in LABEL_LISTS.items()
}

print("\nRoBERTa 訓練任務欄位：", TASK_FIELDS)

print("\nlabel2id：")
print(label2id)

print("\nid2label：")
print(id2label)

print("\nnum_labels_dict：")
print(num_labels_dict)

# ============================================================
# 3.3 定義文字輸入格式：只使用 data
# ============================================================

def clean_text(value):
    """
    將 None / 空字串 / nan 字串清掉。
    """
    if value is None:
        return ""

    value = str(value).strip()

    if value == "":
        return ""

    if value.lower() == "nan":
        return ""

    return value


def get_text(example):
    """
    給 RoBERTa 的輸入文字。

    照之前做法：
    只使用官方原始文本 data，
    不使用 promise_string / evidence_string，
    避免欄位提示造成分數虛高。
    """
    data_text = clean_text(example.get("data", ""))

    if data_text:
        return data_text

    raise KeyError(f"找不到 data 欄位，目前 keys = {example.keys()}")

# ============================================================
# 3.4 測試 get_text()
# ============================================================

print("\n文字輸入範例：")
print(get_text(raw_data[0])[:1000])

print("\n文字長度範例：")
for i in range(3):
    text = get_text(raw_data[i])
    print(f"index {i}: {len(text)} characters")
# Out:
# 官方評分權重：
# promise_status: 0.2
# evidence_status: 0.3
# evidence_quality: 0.35
# verification_timeline: 0.15
#
# RoBERTa 訓練任務欄位： ['promise_status', 'evidence_status']
#
# label2id：
# {'promise_status': {'Yes': 0, 'No': 1}, 'evidence_status': {'Yes': 0, 'No': 1, 'N/A': 2}}
#
# id2label：
# {'promise_status': {0: 'Yes', 1: 'No'}, 'evidence_status': {0: 'Yes', 1: 'No', 2: 'N/A'}}
#
# num_labels_dict：
# {'promise_status': 2, 'evidence_status': 3}
#
# 文字輸入範例：
# 聯發科技除在「工作規則」中依照勞基法明確規定「員工在產假期間公司不得終止勞動契約」外，為支持同仁與其家人度過人生不同階段，自 2024 年起提供女性員工在分娩前後計有 12 週共 84 天的產假；男性員工則可於其配偶懷孕期間陪同產檢或生（流）產日及前後 15 日間請假陪伴，兩者合計共有 10 天陪產（檢）假可運用，陪產（檢）假期間工資照常給付。
#
# 文字長度範例：
# index 0: 173 characters
# index 1: 89 characters
# index 2: 234 characters

# %%
# ============================================================
# Cell 4. 檢查各任務標籤分布，特別確認 Misleading 筆數
# ============================================================

from collections import Counter

# ============================================================
# 4.1 檢查 RoBERTa 要訓練的兩個任務
# ============================================================

print("RoBERTa 訓練任務標籤分布：")

for field in TASK_FIELDS:
    counter = Counter([item.get(field, "MISSING") for item in raw_data])

    print("\n" + "=" * 60)
    print(field)
    print("=" * 60)

    total = sum(counter.values())
    for label, count in counter.items():
        ratio = count / total
        print(f"{label}: {count} 筆 ({ratio:.2%})")

# ============================================================
# 4.2 檢查 GPT-4o + RAG 之後要負責的兩個任務
# ============================================================

RAG_FIELDS = [
    "verification_timeline",
    "evidence_quality"
]

print("\n\nGPT-4o + RAG 任務標籤分布：")

for field in RAG_FIELDS:
    counter = Counter([item.get(field, "MISSING") for item in raw_data])

    print("\n" + "=" * 60)
    print(field)
    print("=" * 60)

    total = sum(counter.values())
    for label, count in counter.items():
        ratio = count / total
        print(f"{label}: {count} 筆 ({ratio:.2%})")

# ============================================================
# 4.3 找出 Misleading 樣本
# ============================================================

misleading_indices = [
    i for i, item in enumerate(raw_data)
    if item.get("evidence_quality") == "Misleading"
]

print("\n" + "=" * 60)
print("Misleading 樣本檢查")
print("=" * 60)
print("Misleading 筆數：", len(misleading_indices))
print("Misleading indices：", misleading_indices)

if len(misleading_indices) > 0:
    idx = misleading_indices[0]
    item = raw_data[idx]

    print("\n唯一 Misleading 樣本內容：")
    print("index:", idx)
    print("id:", item.get("id"))
    print("data:", item.get("data"))
    print("promise_status:", item.get("promise_status"))
    print("verification_timeline:", item.get("verification_timeline"))
    print("evidence_status:", item.get("evidence_status"))
    print("evidence_quality:", item.get("evidence_quality"))
    print("promise_string:", item.get("promise_string"))
    print("evidence_string:", item.get("evidence_string"))
# Out:
# RoBERTa 訓練任務標籤分布：
#
# ============================================================
# promise_status
# ============================================================
# Yes: 814 筆 (81.40%)
# No: 186 筆 (18.60%)
#
# ============================================================
# evidence_status
# ============================================================
# No: 137 筆 (13.70%)
# Yes: 677 筆 (67.70%)
# N/A: 186 筆 (18.60%)
#
#
# GPT-4o + RAG 任務標籤分布：
#
# ============================================================
# verification_timeline
# ============================================================
# already: 366 筆 (36.60%)
# between_2_and_5_years: 238 筆 (23.80%)
# N/A: 186 筆 (18.60%)
# longer_than_5_years: 197 筆 (19.70%)
# within_2_years: 13 筆 (1.30%)
#
# ============================================================
# evidence_quality
# ============================================================
# N/A: 323 筆 (32.30%)
# Not Clear: 124 筆 (12.40%)
# Clear: 552 筆 (55.20%)
# Misleading: 1 筆 (0.10%)
#
# ============================================================
# Misleading 樣本檢查
# ============================================================
# Misleading 筆數： 1
# Misleading indices： [16]
#
# 唯一 Misleading 樣本內容：
# index: 16
# id: 10017
# data: 統一企業致力於穩健經營，確保公司財務穩定與持續成長，並兼顧股東權益、員工發展與社會責任。我們透過創新產品與服務、多元化營運布局及強化供應鏈韌性，提升企業競爭力，並承諾遵循財務與稅務法規，維持高標準的財務透明度與公司治理。
# promise_status: Yes
# verification_timeline: between_2_and_5_years
# evidence_status: Yes
# evidence_quality: Misleading
# promise_string: 統一企業致力於穩健經營，確保公司財務穩定與持續成長，並兼顧股東權益、員工發展與社會責任。我
# evidence_string: 我們透過創新產品與服務、多元化營運布局及強化供應鏈韌性，提升企業競爭力，並承諾遵循財務與稅務法規，維持高標準的財務透明度與公司治理。

# %%
# ============================================================
# Cell 5. 切分 train / valid / test
# 固定將唯一 Misleading 樣本放入 test_data
# ============================================================

from sklearn.model_selection import train_test_split
from collections import Counter

# ============================================================
# 5.1 分離 Misleading 與非 Misleading 資料
# ============================================================

misleading_data = [
    item for item in raw_data
    if item.get("evidence_quality") == "Misleading"
]

non_misleading_data = [
    item for item in raw_data
    if item.get("evidence_quality") != "Misleading"
]

print("Misleading 筆數：", len(misleading_data))
print("非 Misleading 筆數：", len(non_misleading_data))

if len(misleading_data) != 1:
    raise ValueError("Misleading 筆數不是 1，請先檢查資料。")

misleading_id = misleading_data[0].get("id")
print("固定放入 test_data 的 Misleading id：", misleading_id)

# ============================================================
# 5.2 從 999 筆非 Misleading 中切出 train / valid / test_normal
# ============================================================

# 先切出 99 筆作為普通 test
train_valid_data, test_normal_data = train_test_split(
    non_misleading_data,
    test_size=99,
    random_state=SEED,
    shuffle=True
)

# 剩下 900 筆再切 train 800 / valid 100
train_data, valid_data = train_test_split(
    train_valid_data,
    test_size=100,
    random_state=SEED,
    shuffle=True
)

# test_data = 99 筆普通資料 + 1 筆 Misleading
test_data = test_normal_data + misleading_data

# 打亂 test_data，避免 Misleading 永遠在最後一筆
random.shuffle(test_data)

# ============================================================
# 5.3 檢查切分結果
# ============================================================

print("\n切分結果：")
print("train_data 筆數：", len(train_data))
print("valid_data 筆數：", len(valid_data))
print("test_data 筆數：", len(test_data))

assert len(train_data) == 800
assert len(valid_data) == 100
assert len(test_data) == 100

# 檢查資料是否重複
train_ids = set([item["id"] for item in train_data])
valid_ids = set([item["id"] for item in valid_data])
test_ids = set([item["id"] for item in test_data])

print("\n資料重疊檢查：")
print("train ∩ valid:", len(train_ids & valid_ids))
print("train ∩ test :", len(train_ids & test_ids))
print("valid ∩ test :", len(valid_ids & test_ids))

assert len(train_ids & valid_ids) == 0
assert len(train_ids & test_ids) == 0
assert len(valid_ids & test_ids) == 0

# 檢查 Misleading 是否在 test_data
print("\nMisleading 位置檢查：")
print("Misleading 是否在 train_data:", misleading_id in train_ids)
print("Misleading 是否在 valid_data:", misleading_id in valid_ids)
print("Misleading 是否在 test_data :", misleading_id in test_ids)

assert misleading_id not in train_ids
assert misleading_id not in valid_ids
assert misleading_id in test_ids

# ============================================================
# 5.4 查看各 split 的標籤分布
# ============================================================

def print_split_distribution(name, data_split):
    print("\n" + "=" * 80)
    print(name)
    print("=" * 80)

    for field in [
        "promise_status",
        "evidence_status",
        "verification_timeline",
        "evidence_quality"
    ]:
        counter = Counter([item.get(field, "MISSING") for item in data_split])
        total = sum(counter.values())

        print(f"\n{field}:")
        for label, count in counter.items():
            print(f"  {label}: {count} 筆 ({count / total:.2%})")

print_split_distribution("train_data", train_data)
print_split_distribution("valid_data", valid_data)
print_split_distribution("test_data", test_data)

# ============================================================
# 5.5 儲存切分結果
# ============================================================

split_obj = {
    "train_data": train_data,
    "valid_data": valid_data,
    "test_data": test_data,
    "task_fields": TASK_FIELDS,
    "label_lists": LABEL_LISTS,
    "official_weights": OFFICIAL_WEIGHTS,
    "seed": SEED,
    "misleading_id_in_test": misleading_id,
    "note": "The unique Misleading sample is fixed in test_data."
}

with open(SAVE_SPLIT_PATH, "w", encoding="utf-8") as f:
    json.dump(split_obj, f, ensure_ascii=False, indent=2)

print("\n✅ 已儲存切分資料：", SAVE_SPLIT_PATH)
# Out:
# Misleading 筆數： 1
# 非 Misleading 筆數： 999
# 固定放入 test_data 的 Misleading id： 10017
#
# 切分結果：
# train_data 筆數： 800
# valid_data 筆數： 100
# test_data 筆數： 100
#
# 資料重疊檢查：
# train ∩ valid: 0
# train ∩ test : 0
# valid ∩ test : 0
#
# Misleading 位置檢查：
# Misleading 是否在 train_data: False
# Misleading 是否在 valid_data: False
# Misleading 是否在 test_data : True
#
# ================================================================================
# train_data
# ================================================================================
#
# promise_status:
#   Yes: 652 筆 (81.50%)
#   No: 148 筆 (18.50%)
#
# evidence_status:
#   Yes: 542 筆 (67.75%)
#   No: 110 筆 (13.75%)
#   N/A: 148 筆 (18.50%)
#
# verification_timeline:
#   already: 294 筆 (36.75%)
#   between_2_and_5_years: 187 筆 (23.38%)
#   N/A: 148 筆 (18.50%)
#   longer_than_5_years: 160 筆 (20.00%)
#   within_2_years: 11 筆 (1.38%)
#
# evidence_quality:
#   Clear: 439 筆 (54.87%)
#   N/A: 258 筆 (32.25%)
#   Not Clear: 103 筆 (12.88%)
#
# ================================================================================
# valid_data
# ================================================================================
#
# promise_status:
#   Yes: 79 筆 (79.00%)
#   No: 21 筆 (21.00%)
#
# evidence_status:
#   Yes: 68 筆 (68.00%)
#   N/A: 21 筆 (21.00%)
#   No: 11 筆 (11.00%)
#
# verification_timeline:
#   longer_than_5_years: 19 筆 (19.00%)
#   N/A: 21 筆 (21.00%)
#   between_2_and_5_years: 25 筆 (25.00%)
#   already: 34 筆 (34.00%)
#   within_2_years: 1 筆 (1.00%)
#
# evidence_quality:
#   Clear: 58 筆 (58.00%)
#   N/A: 32 筆 (32.00%)
#   Not Clear: 10 筆 (10.00%)
#
# ================================================================================
# test_data
# ================================================================================
#
# promise_status:
#   Yes: 83 筆 (83.00%)
#   No: 17 筆 (17.00%)
#
# evidence_status:
#   Yes: 67 筆 (67.00%)
#   N/A: 17 筆 (17.00%)
#   No: 16 筆 (16.00%)
#
# verification_timeline:
#   already: 38 筆 (38.00%)
#   longer_than_5_years: 18 筆 (18.00%)
#   N/A: 17 筆 (17.00%)
#   between_2_and_5_years: 26 筆 (26.00%)
#   within_2_years: 1 筆 (1.00%)
#
# evidence_quality:
#   Clear: 55 筆 (55.00%)
#   Not Clear: 11 筆 (11.00%)
#   N/A: 33 筆 (33.00%)
#   Misleading: 1 筆 (1.00%)
#
# ✅ 已儲存切分資料： /content/drive/MyDrive/ESG_Project/task13_train_valid_test_split.json

# %%
# ============================================================
# Cell 6. 建立 Dataset / DataLoader
# ============================================================

from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer

# ============================================================
# 6.1 設定模型與 tokenize 參數
# ============================================================

MODEL_NAME = "hfl/chinese-roberta-wwm-ext-large"
MAX_LEN = 512
BATCH_SIZE = 2

print("載入 tokenizer：", MODEL_NAME)
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# ============================================================
# 6.2 建立 Dataset
# ============================================================

class ESGTask13Dataset(Dataset):
    def __init__(self, data, tokenizer, max_len=512):
        self.data = data
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        text = get_text(item)

        encoding = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_len,
            return_tensors="pt"
        )

        labels = {}

        for field in TASK_FIELDS:
            label = item[field]

            if label not in label2id[field]:
                raise ValueError(
                    f"未知標籤：field={field}, label={label}, id={item.get('id')}"
                )

            labels[field] = torch.tensor(
                label2id[field][label],
                dtype=torch.long
            )

        return {
            "id": item.get("id"),
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "labels": labels
        }

# ============================================================
# 6.3 Collate function
# ============================================================

def collate_fn(batch):
    ids = [x["id"] for x in batch]

    input_ids = torch.stack([x["input_ids"] for x in batch])
    attention_mask = torch.stack([x["attention_mask"] for x in batch])

    labels = {
        field: torch.stack([x["labels"][field] for x in batch])
        for field in TASK_FIELDS
    }

    return {
        "ids": ids,
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "labels": labels
    }

# ============================================================
# 6.4 建立 Dataset
# ============================================================

train_dataset = ESGTask13Dataset(train_data, tokenizer, MAX_LEN)
valid_dataset = ESGTask13Dataset(valid_data, tokenizer, MAX_LEN)
test_dataset = ESGTask13Dataset(test_data, tokenizer, MAX_LEN)

print("train_dataset 筆數：", len(train_dataset))
print("valid_dataset 筆數：", len(valid_dataset))
print("test_dataset 筆數：", len(test_dataset))

# ============================================================
# 6.5 建立 DataLoader
# ============================================================

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    collate_fn=collate_fn
)

valid_loader = DataLoader(
    valid_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    collate_fn=collate_fn
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    collate_fn=collate_fn
)

print("✅ DataLoader 建立完成")

# ============================================================
# 6.6 測試一個 batch
# ============================================================

batch = next(iter(train_loader))

print("\nBatch 測試：")
print("ids:", batch["ids"])
print("input_ids shape:", batch["input_ids"].shape)
print("attention_mask shape:", batch["attention_mask"].shape)

for field in TASK_FIELDS:
    print(f"{field} labels:", batch["labels"][field])
    print(f"{field} labels shape:", batch["labels"][field].shape)
# Out:
# 載入 tokenizer： hfl/chinese-roberta-wwm-ext-large
# config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/19.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# train_dataset 筆數： 800
# valid_dataset 筆數： 100
# test_dataset 筆數： 100
# ✅ DataLoader 建立完成
#
# Batch 測試：
# ids: [10576, 10764]
# input_ids shape: torch.Size([2, 512])
# attention_mask shape: torch.Size([2, 512])
# promise_status labels: tensor([0, 0])
# promise_status labels shape: torch.Size([2])
# evidence_status labels: tensor([0, 0])
# evidence_status labels shape: torch.Size([2])

# %%
# ============================================================
# Cell 7. 建立 Single RoBERTa Task 1 + Task 3 模型
# ============================================================

import torch.nn as nn
from transformers import AutoModel

# ============================================================
# 7.1 定義模型
# ============================================================

class SingleRoBERTaTask13(nn.Module):
    def __init__(self, model_name, num_labels_dict, dropout_rate=0.1):
        super().__init__()

        self.roberta = AutoModel.from_pretrained(model_name)

        # 開啟 gradient checkpointing，降低 GPU 記憶體使用量
        self.roberta.gradient_checkpointing_enable()

        hidden_size = self.roberta.config.hidden_size

        self.dropout = nn.Dropout(dropout_rate)

        # 只建立 TASK_FIELDS 裡面的分類頭
        self.classifiers = nn.ModuleDict({
            field: nn.Linear(hidden_size, num_labels_dict[field])
            for field in TASK_FIELDS
        })

        # 初始化分類頭
        for classifier in self.classifiers.values():
            nn.init.normal_(classifier.weight, std=0.02)
            nn.init.zeros_(classifier.bias)

    def forward(self, input_ids, attention_mask):
        outputs = self.roberta(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        # 使用 [CLS] token
        cls_output = outputs.last_hidden_state[:, 0, :]
        cls_output = self.dropout(cls_output)

        logits = {
            field: self.classifiers[field](cls_output)
            for field in TASK_FIELDS
        }

        return logits

# ============================================================
# 7.2 建立模型
# ============================================================

model = SingleRoBERTaTask13(
    model_name=MODEL_NAME,
    num_labels_dict=num_labels_dict,
    dropout_rate=0.1
)

model.to(device)

print("✅ 模型建立完成")
print("使用模型：", MODEL_NAME)
print("任務欄位：", TASK_FIELDS)
print("\n分類頭：")
print(model.classifiers)

# ============================================================
# 7.3 測試 forward pass
# ============================================================

batch = next(iter(train_loader))

input_ids = batch["input_ids"].to(device)
attention_mask = batch["attention_mask"].to(device)

model.eval()

with torch.no_grad():
    logits = model(input_ids=input_ids, attention_mask=attention_mask)

print("\nForward pass 測試：")
for field in TASK_FIELDS:
    print(f"{field} logits shape:", logits[field].shape)

# 清理 GPU cache
torch.cuda.empty_cache()
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.31G [00:00<?, ?B/s]
# Exception in thread Thread-auto_conversion:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 761, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/api/models/hfl/chinese-roberta-wwm-ext-large/discussions?p=0'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 116, in auto_conversion
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 95, in auto_conversion
#     sha = get_conversion_pr_reference(api, pretrained_model_name_or_path, **cached_file_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 68, in get_conversion_pr_reference
#     pr = previous_pr(api, model_id, pr_title, token=token)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 14, in previous_pr
#     for discussion in get_repo_discussions(repo_id=model_id, token=token):
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 6949, in get_repo_discussions
#     discussions, has_next = _fetch_discussion_page(page_index=page_index)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 6938, in _fetch_discussion_page
#     hf_raise_for_status(resp)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 849, in hf_raise_for_status
#     raise _format(HfHubHTTPError, message, response) from e
# huggingface_hub.errors.HfHubHTTPError: (Request ID: Root=1-69fc4e16-08ee0f6b081a99531cdb486a;4b50d17e-aebe-438a-95dc-2abe72010d39)
#
# 403 Forbidden: Discussions are disabled for this repo.
# Cannot access content at: https://huggingface.co/api/models/hfl/chinese-roberta-wwm-ext-large/discussions?p=0.
# Make sure your token has the correct permissions.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: hfl/chinese-roberta-wwm-ext-large
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ 模型建立完成
# 使用模型： hfl/chinese-roberta-wwm-ext-large
# 任務欄位： ['promise_status', 'evidence_status']
#
# 分類頭：
# ModuleDict(
#   (promise_status): Linear(in_features=1024, out_features=2, bias=True)
#   (evidence_status): Linear(in_features=1024, out_features=3, bias=True)
# )
#
# Forward pass 測試：
# promise_status logits shape: torch.Size([2, 2])
# evidence_status logits shape: torch.Size([2, 3])

# %%
# ============================================================
# Cell 8. 設定 Optimizer、Scheduler、Loss
# ============================================================

from transformers import get_linear_schedule_with_warmup
from torch.optim import AdamW
import torch.nn as nn

# ============================================================
# 8.1 訓練超參數
# ============================================================

EPOCHS = 10
LR = 1e-5
ACCUM_STEPS = 16
MAX_GRAD_NORM = 1.0

# 等效 batch size = BATCH_SIZE * ACCUM_STEPS
EFFECTIVE_BATCH_SIZE = BATCH_SIZE * ACCUM_STEPS

print("訓練超參數：")
print("EPOCHS:", EPOCHS)
print("LR:", LR)
print("BATCH_SIZE:", BATCH_SIZE)
print("ACCUM_STEPS:", ACCUM_STEPS)
print("EFFECTIVE_BATCH_SIZE:", EFFECTIVE_BATCH_SIZE)

# ============================================================
# 8.2 Loss function
# ============================================================

loss_fns = {
    field: nn.CrossEntropyLoss()
    for field in TASK_FIELDS
}

# 根據官方權重，任務 1:任務 3 = 0.20:0.30 = 0.40:0.60
FIELD_WEIGHTS = {
    "promise_status": 0.40,
    "evidence_status": 0.60
}

print("\n訓練 loss 權重：")
print(FIELD_WEIGHTS)

# ============================================================
# 8.3 Optimizer
# ============================================================

optimizer = AdamW(
    model.parameters(),
    lr=LR
)

# ============================================================
# 8.4 Scheduler
# ============================================================

# 注意：使用 ceil，避免 len(train_loader) 不能整除 ACCUM_STEPS 時少算 step
import math

steps_per_epoch = math.ceil(len(train_loader) / ACCUM_STEPS)
total_training_steps = steps_per_epoch * EPOCHS
warmup_steps = int(total_training_steps * 0.1)

scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=warmup_steps,
    num_training_steps=total_training_steps
)

print("\nScheduler 設定：")
print("len(train_loader):", len(train_loader))
print("steps_per_epoch:", steps_per_epoch)
print("total_training_steps:", total_training_steps)
print("warmup_steps:", warmup_steps)

# ============================================================
# 8.5 Mixed precision scaler
# ============================================================

scaler = torch.cuda.amp.GradScaler(enabled=torch.cuda.is_available())

print("\n✅ Cell 8 設定完成")
# Out:
# 訓練超參數：
# EPOCHS: 10
# LR: 1e-05
# BATCH_SIZE: 2
# ACCUM_STEPS: 16
# EFFECTIVE_BATCH_SIZE: 32
#
# 訓練 loss 權重：
# {'promise_status': 0.4, 'evidence_status': 0.6}
#
# Scheduler 設定：
# len(train_loader): 400
# steps_per_epoch: 25
# total_training_steps: 250
# warmup_steps: 25
#
# ✅ Cell 8 設定完成

# %%
# ============================================================
# Cell 9. 評估函數：使用官方權重計算 RoBERTa score
# ============================================================

from sklearn.metrics import classification_report, f1_score, accuracy_score
import numpy as np

# ============================================================
# 9.1 評估函數
# ============================================================

def evaluate(model, dataloader, desc="Evaluating"):
    model.eval()

    all_true = {field: [] for field in TASK_FIELDS}
    all_pred = {field: [] for field in TASK_FIELDS}

    total_loss = 0.0
    total_batches = 0

    with torch.no_grad():
        for batch in tqdm(dataloader, desc=desc, leave=False):
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)

            labels = {
                field: batch["labels"][field].to(device)
                for field in TASK_FIELDS
            }

            with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
                logits = model(
                    input_ids=input_ids,
                    attention_mask=attention_mask
                )

                loss = 0.0
                for field in TASK_FIELDS:
                    field_loss = loss_fns[field](
                        logits[field],
                        labels[field]
                    )
                    loss += FIELD_WEIGHTS[field] * field_loss

            total_loss += loss.item()
            total_batches += 1

            for field in TASK_FIELDS:
                preds = torch.argmax(logits[field], dim=1)

                all_true[field].extend(labels[field].detach().cpu().numpy().tolist())
                all_pred[field].extend(preds.detach().cpu().numpy().tolist())

    results = {}

    for field in TASK_FIELDS:
        label_ids = list(range(len(LABEL_LISTS[field])))

        macro_f1 = f1_score(
            all_true[field],
            all_pred[field],
            labels=label_ids,
            average="macro",
            zero_division=0
        )

        micro_f1 = f1_score(
            all_true[field],
            all_pred[field],
            labels=label_ids,
            average="micro",
            zero_division=0
        )

        acc = accuracy_score(
            all_true[field],
            all_pred[field]
        )

        results[field] = {
            "macro_f1": macro_f1,
            "micro_f1": micro_f1,
            "accuracy": acc,
            "y_true": all_true[field],
            "y_pred": all_pred[field]
        }

    # ========================================================
    # 官方權重正規化版分數
    # promise_status 0.20 + evidence_status 0.30 = 0.50
    # ========================================================

    weighted_sum = 0.0
    used_weight_sum = 0.0

    for field in TASK_FIELDS:
        weighted_sum += results[field]["macro_f1"] * OFFICIAL_WEIGHTS[field]
        used_weight_sum += OFFICIAL_WEIGHTS[field]

    roberta_score = weighted_sum / used_weight_sum

    avg_loss = total_loss / max(total_batches, 1)

    return {
        "loss": avg_loss,
        "roberta_score": roberta_score,
        "field_results": results
    }

# ============================================================
# 9.2 印出 classification report
# ============================================================

def print_eval_report(eval_output):
    print(f"Loss: {eval_output['loss']:.4f}")
    print(f"RoBERTa weighted score: {eval_output['roberta_score']:.4f}")

    for field in TASK_FIELDS:
        result = eval_output["field_results"][field]

        label_ids = list(range(len(LABEL_LISTS[field])))
        target_names = LABEL_LISTS[field]

        print("\n" + "=" * 70)
        print(field)
        print("=" * 70)

        print(classification_report(
            result["y_true"],
            result["y_pred"],
            labels=label_ids,
            target_names=target_names,
            zero_division=0
        ))

        print(f"Macro F1: {result['macro_f1']:.4f}")
        print(f"Micro F1: {result['micro_f1']:.4f}")
        print(f"Accuracy: {result['accuracy']:.4f}")

# ============================================================
# 9.3 先測試一次 valid_loader，確認評估函數能跑
# ============================================================

print("開始測試 evaluate()...")

valid_eval_test = evaluate(
    model,
    valid_loader,
    desc="Testing evaluate"
)

print_eval_report(valid_eval_test)

print("\n✅ Cell 9 評估函數建立完成")
# Out:
# 開始測試 evaluate()...
# Loss: 1.0215
# RoBERTa weighted score: 0.2371
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.76      0.33      0.46        79
#           No       0.20      0.62      0.30        21
#
#     accuracy                           0.39       100
#    macro avg       0.48      0.47      0.38       100
# weighted avg       0.65      0.39      0.43       100
#
# Macro F1: 0.3795
# Micro F1: 0.3900
# Accuracy: 0.3900
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.50      0.01      0.03        68
#           No       0.08      0.36      0.12        11
#          N/A       0.20      0.43      0.27        21
#
#     accuracy                           0.14       100
#    macro avg       0.26      0.27      0.14       100
# weighted avg       0.39      0.14      0.09       100
#
# Macro F1: 0.1421
# Micro F1: 0.1400
# Accuracy: 0.1400
#
# ✅ Cell 9 評估函數建立完成

# %%
# ============================================================
# Cell 10. 正式訓練 Single RoBERTa Task 1 + Task 3
# ============================================================

best_score = -1.0
best_epoch = -1
history = []

optimizer.zero_grad()

for epoch in range(1, EPOCHS + 1):
    model.train()

    total_train_loss = 0.0
    step_count = 0

    progress_bar = tqdm(
        train_loader,
        desc=f"Epoch {epoch}/{EPOCHS}"
    )

    for step, batch in enumerate(progress_bar, start=1):
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)

        labels = {
            field: batch["labels"][field].to(device)
            for field in TASK_FIELDS
        }

        with torch.cuda.amp.autocast(enabled=torch.cuda.is_available()):
            logits = model(
                input_ids=input_ids,
                attention_mask=attention_mask
            )

            loss = 0.0

            for field in TASK_FIELDS:
                field_loss = loss_fns[field](
                    logits[field],
                    labels[field]
                )
                loss += FIELD_WEIGHTS[field] * field_loss

            loss = loss / ACCUM_STEPS

        scaler.scale(loss).backward()

        total_train_loss += loss.item() * ACCUM_STEPS
        step_count += 1

        if step % ACCUM_STEPS == 0 or step == len(train_loader):
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(
                model.parameters(),
                MAX_GRAD_NORM
            )

            scaler.step(optimizer)
            scaler.update()

            scheduler.step()
            optimizer.zero_grad()

        avg_train_loss = total_train_loss / max(step_count, 1)

        progress_bar.set_postfix({
            "loss": f"{avg_train_loss:.4f}"
        })

    avg_train_loss = total_train_loss / max(step_count, 1)

    print("\n" + "=" * 90)
    print(f"Epoch {epoch}/{EPOCHS} 訓練完成")
    print(f"Train Loss: {avg_train_loss:.4f}")

    valid_eval = evaluate(
        model,
        valid_loader,
        desc=f"Valid Epoch {epoch}"
    )

    print_eval_report(valid_eval)

    epoch_record = {
        "epoch": epoch,
        "train_loss": avg_train_loss,
        "valid_loss": valid_eval["loss"],
        "valid_roberta_score": valid_eval["roberta_score"],
        "field_results": {
            field: {
                "macro_f1": valid_eval["field_results"][field]["macro_f1"],
                "micro_f1": valid_eval["field_results"][field]["micro_f1"],
                "accuracy": valid_eval["field_results"][field]["accuracy"]
            }
            for field in TASK_FIELDS
        }
    }

    history.append(epoch_record)

    if valid_eval["roberta_score"] > best_score:
        best_score = valid_eval["roberta_score"]
        best_epoch = epoch

        save_obj = {
            "model_state_dict": model.state_dict(),
            "model_name": MODEL_NAME,
            "task_fields": TASK_FIELDS,
            "label_lists": LABEL_LISTS,
            "label2id": label2id,
            "id2label": id2label,
            "num_labels_dict": num_labels_dict,
            "max_len": MAX_LEN,
            "official_weights": OFFICIAL_WEIGHTS,
            "field_weights": FIELD_WEIGHTS,
            "best_score": best_score,
            "best_epoch": best_epoch,
            "seed": SEED
        }

        torch.save(save_obj, SAVE_MODEL_PATH)

        print("\n✅ 儲存新的最佳模型")
        print("SAVE_MODEL_PATH:", SAVE_MODEL_PATH)
        print("Best Epoch:", best_epoch)
        print("Best RoBERTa Score:", f"{best_score:.4f}")

    print("=" * 90)

    # 清理 GPU cache
    torch.cuda.empty_cache()

print("\n訓練完成")
print("Best Epoch:", best_epoch)
print("Best RoBERTa Score:", f"{best_score:.4f}")
print("Best Model Path:", SAVE_MODEL_PATH)
# Out:
# Epoch 1/10: 100%|██████████| 400/400 [01:57<00:00,  3.42it/s, loss=0.8211]
# ==========================================================================================
# Epoch 1/10 訓練完成
# Train Loss: 0.8211
# Loss: 0.7045
# RoBERTa weighted score: 0.3384
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.79      1.00      0.88        79
#           No       0.00      0.00      0.00        21
#
#     accuracy                           0.79       100
#    macro avg       0.40      0.50      0.44       100
# weighted avg       0.62      0.79      0.70       100
#
# Macro F1: 0.4413
# Micro F1: 0.7900
# Accuracy: 0.7900
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.68      1.00      0.81        68
#           No       0.00      0.00      0.00        11
#          N/A       0.00      0.00      0.00        21
#
#     accuracy                           0.68       100
#    macro avg       0.23      0.33      0.27       100
# weighted avg       0.46      0.68      0.55       100
#
# Macro F1: 0.2698
# Micro F1: 0.6800
# Accuracy: 0.6800
#
# ✅ 儲存新的最佳模型
# SAVE_MODEL_PATH: /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt
# Best Epoch: 1
# Best RoBERTa Score: 0.3384
# ==========================================================================================
# Epoch 2/10: 100%|██████████| 400/400 [01:58<00:00,  3.37it/s, loss=0.6155]
# ==========================================================================================
# Epoch 2/10 訓練完成
# Train Loss: 0.6155
# Loss: 0.6413
# RoBERTa weighted score: 0.3523
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.79      0.99      0.88        79
#           No       0.00      0.00      0.00        21
#
#     accuracy                           0.78       100
#    macro avg       0.39      0.49      0.44       100
# weighted avg       0.62      0.78      0.69       100
#
# Macro F1: 0.4382
# Micro F1: 0.7800
# Accuracy: 0.7800
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.69      0.97      0.80        68
#           No       0.00      0.00      0.00        11
#          N/A       0.25      0.05      0.08        21
#
#     accuracy                           0.67       100
#    macro avg       0.31      0.34      0.29       100
# weighted avg       0.52      0.67      0.56       100
#
# Macro F1: 0.2950
# Micro F1: 0.6700
# Accuracy: 0.6700
#
# ✅ 儲存新的最佳模型
# SAVE_MODEL_PATH: /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt
# Best Epoch: 2
# Best RoBERTa Score: 0.3523
# ==========================================================================================
# Epoch 3/10: 100%|██████████| 400/400 [01:52<00:00,  3.54it/s, loss=0.4497]
# ==========================================================================================
# Epoch 3/10 訓練完成
# Train Loss: 0.4497
# Loss: 0.6291
# RoBERTa weighted score: 0.5294
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.83      0.97      0.90        79
#           No       0.71      0.24      0.36        21
#
#     accuracy                           0.82       100
#    macro avg       0.77      0.61      0.63       100
# weighted avg       0.80      0.82      0.78       100
#
# Macro F1: 0.6262
# Micro F1: 0.8200
# Accuracy: 0.8200
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.76      0.85      0.81        68
#           No       0.22      0.18      0.20        11
#          N/A       0.47      0.33      0.39        21
#
#     accuracy                           0.67       100
#    macro avg       0.48      0.46      0.46       100
# weighted avg       0.64      0.67      0.65       100
#
# Macro F1: 0.4648
# Micro F1: 0.6700
# Accuracy: 0.6700
#
# ✅ 儲存新的最佳模型
# SAVE_MODEL_PATH: /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt
# Best Epoch: 3
# Best RoBERTa Score: 0.5294
# ==========================================================================================
# Epoch 4/10: 100%|██████████| 400/400 [01:52<00:00,  3.55it/s, loss=0.2933]
# ==========================================================================================
# Epoch 4/10 訓練完成
# Train Loss: 0.2933
# Loss: 0.6700
# RoBERTa weighted score: 0.5820
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.87      0.91      0.89        79
#           No       0.59      0.48      0.53        21
#
#     accuracy                           0.82       100
#    macro avg       0.73      0.69      0.71       100
# weighted avg       0.81      0.82      0.81       100
#
# Macro F1: 0.7076
# Micro F1: 0.8200
# Accuracy: 0.8200
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.76      0.76      0.76        68
#           No       0.29      0.36      0.32        11
#          N/A       0.44      0.38      0.41        21
#
#     accuracy                           0.64       100
#    macro avg       0.50      0.50      0.50       100
# weighted avg       0.64      0.64      0.64       100
#
# Macro F1: 0.4983
# Micro F1: 0.6400
# Accuracy: 0.6400
#
# ✅ 儲存新的最佳模型
# SAVE_MODEL_PATH: /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt
# Best Epoch: 4
# Best RoBERTa Score: 0.5820
# ==========================================================================================
# Epoch 5/10: 100%|██████████| 400/400 [01:52<00:00,  3.54it/s, loss=0.1788]
# ==========================================================================================
# Epoch 5/10 訓練完成
# Train Loss: 0.1788
# Loss: 0.7361
# RoBERTa weighted score: 0.6360
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.89      0.86      0.88        79
#           No       0.54      0.62      0.58        21
#
#     accuracy                           0.81       100
#    macro avg       0.72      0.74      0.73       100
# weighted avg       0.82      0.81      0.81       100
#
# Macro F1: 0.7276
# Micro F1: 0.8100
# Accuracy: 0.8100
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.79      0.79      0.79        68
#           No       0.45      0.45      0.45        11
#          N/A       0.48      0.48      0.48        21
#
#     accuracy                           0.69       100
#    macro avg       0.57      0.57      0.57       100
# weighted avg       0.69      0.69      0.69       100
#
# Macro F1: 0.5750
# Micro F1: 0.6900
# Accuracy: 0.6900
#
# ✅ 儲存新的最佳模型
# SAVE_MODEL_PATH: /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt
# Best Epoch: 5
# Best RoBERTa Score: 0.6360
# ==========================================================================================
# Epoch 6/10: 100%|██████████| 400/400 [01:53<00:00,  3.51it/s, loss=0.0990]
# ==========================================================================================
# Epoch 6/10 訓練完成
# Train Loss: 0.0990
# Loss: 0.9597
# RoBERTa weighted score: 0.6178
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.86      0.97      0.91        79
#           No       0.80      0.38      0.52        21
#
#     accuracy                           0.85       100
#    macro avg       0.83      0.68      0.71       100
# weighted avg       0.84      0.85      0.83       100
#
# Macro F1: 0.7137
# Micro F1: 0.8500
# Accuracy: 0.8500
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.79      0.96      0.87        68
#           No       0.40      0.36      0.38        11
#          N/A       0.75      0.29      0.41        21
#
#     accuracy                           0.75       100
#    macro avg       0.65      0.54      0.55       100
# weighted avg       0.74      0.75      0.72       100
#
# Macro F1: 0.5538
# Micro F1: 0.7500
# Accuracy: 0.7500
# ==========================================================================================
# Epoch 7/10: 100%|██████████| 400/400 [01:45<00:00,  3.78it/s, loss=0.0492]
# ==========================================================================================
# Epoch 7/10 訓練完成
# Train Loss: 0.0492
# Loss: 1.0577
# RoBERTa weighted score: 0.5916
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.85      0.96      0.90        79
#           No       0.73      0.38      0.50        21
#
#     accuracy                           0.84       100
#    macro avg       0.79      0.67      0.70       100
# weighted avg       0.83      0.84      0.82       100
#
# Macro F1: 0.7024
# Micro F1: 0.8400
# Accuracy: 0.8400
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.78      0.94      0.85        68
#           No       0.33      0.27      0.30        11
#          N/A       0.67      0.29      0.40        21
#
#     accuracy                           0.73       100
#    macro avg       0.59      0.50      0.52       100
# weighted avg       0.71      0.73      0.70       100
#
# Macro F1: 0.5178
# Micro F1: 0.7300
# Accuracy: 0.7300
# ==========================================================================================
# Epoch 8/10: 100%|██████████| 400/400 [01:45<00:00,  3.78it/s, loss=0.0207]
# ==========================================================================================
# Epoch 8/10 訓練完成
# Train Loss: 0.0207
# Loss: 1.1352
# RoBERTa weighted score: 0.5958
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.85      0.95      0.90        79
#           No       0.67      0.38      0.48        21
#
#     accuracy                           0.83       100
#    macro avg       0.76      0.67      0.69       100
# weighted avg       0.81      0.83      0.81       100
#
# Macro F1: 0.6915
# Micro F1: 0.8300
# Accuracy: 0.8300
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.79      0.87      0.83        68
#           No       0.29      0.45      0.36        11
#          N/A       0.75      0.29      0.41        21
#
#     accuracy                           0.70       100
#    macro avg       0.61      0.54      0.53       100
# weighted avg       0.72      0.70      0.69       100
#
# Macro F1: 0.5320
# Micro F1: 0.7000
# Accuracy: 0.7000
# ==========================================================================================
# Epoch 9/10: 100%|██████████| 400/400 [01:45<00:00,  3.80it/s, loss=0.0117]
# ==========================================================================================
# Epoch 9/10 訓練完成
# Train Loss: 0.0117
# Loss: 1.1901
# RoBERTa weighted score: 0.5905
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.85      0.96      0.90        79
#           No       0.73      0.38      0.50        21
#
#     accuracy                           0.84       100
#    macro avg       0.79      0.67      0.70       100
# weighted avg       0.83      0.84      0.82       100
#
# Macro F1: 0.7024
# Micro F1: 0.8400
# Accuracy: 0.8400
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.78      0.88      0.83        68
#           No       0.29      0.36      0.32        11
#          N/A       0.67      0.29      0.40        21
#
#     accuracy                           0.70       100
#    macro avg       0.58      0.51      0.52       100
# weighted avg       0.70      0.70      0.68       100
#
# Macro F1: 0.5159
# Micro F1: 0.7000
# Accuracy: 0.7000
# ==========================================================================================
# Epoch 10/10: 100%|██████████| 400/400 [01:45<00:00,  3.79it/s, loss=0.0056]
# ==========================================================================================
# Epoch 10/10 訓練完成
# Train Loss: 0.0056
# Loss: 1.1995
# RoBERTa weighted score: 0.6045
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.85      0.96      0.90        79
#           No       0.73      0.38      0.50        21
#
#     accuracy                           0.84       100
#    macro avg       0.79      0.67      0.70       100
# weighted avg       0.83      0.84      0.82       100
#
# Macro F1: 0.7024
# Micro F1: 0.8400
# Accuracy: 0.8400
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.79      0.88      0.83        68
#           No       0.33      0.45      0.38        11
#          N/A       0.67      0.29      0.40        21
#
#     accuracy                           0.71       100
#    macro avg       0.60      0.54      0.54       100
# weighted avg       0.71      0.71      0.69       100
#
# Macro F1: 0.5393
# Micro F1: 0.7100
# Accuracy: 0.7100
# ==========================================================================================
#
# 訓練完成
# Best Epoch: 5
# Best RoBERTa Score: 0.6360
# Best Model Path: /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt

# %%
# ============================================================
# Cell 11. 載入最佳模型並在 test_data 評估
# ============================================================

checkpoint = torch.load(SAVE_MODEL_PATH, map_location=device)

print("載入模型：", SAVE_MODEL_PATH)
print("Best Epoch:", checkpoint["best_epoch"])
print("Best Valid RoBERTa Score:", checkpoint["best_score"])

best_model = SingleRoBERTaTask13(
    model_name=checkpoint["model_name"],
    num_labels_dict=checkpoint["num_labels_dict"],
    dropout_rate=0.1
)

best_model.load_state_dict(checkpoint["model_state_dict"])
best_model.to(device)
best_model.eval()

print("\n✅ 最佳模型載入完成")

test_eval = evaluate(
    best_model,
    test_loader,
    desc="Testing Best Model"
)

print("\n" + "=" * 90)
print("Best Model on test_data")
print("=" * 90)
print_eval_report(test_eval)
# Out:
# 載入模型： /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt
# Best Epoch: 5
# Best Valid RoBERTa Score: 0.6360101420822484
# Exception in thread Thread-auto_conversion:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 761, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/api/models/hfl/chinese-roberta-wwm-ext-large/discussions?p=0'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 116, in auto_conversion
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 95, in auto_conversion
#     sha = get_conversion_pr_reference(api, pretrained_model_name_or_path, **cached_file_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 68, in get_conversion_pr_reference
#     pr = previous_pr(api, model_id, pr_title, token=token)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 14, in previous_pr
#     for discussion in get_repo_discussions(repo_id=model_id, token=token):
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 6949, in get_repo_discussions
#     discussions, has_next = _fetch_discussion_page(page_index=page_index)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 6938, in _fetch_discussion_page
#     hf_raise_for_status(resp)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 849, in hf_raise_for_status
#     raise _format(HfHubHTTPError, message, response) from e
# huggingface_hub.errors.HfHubHTTPError: (Request ID: Root=1-69fc4e4b-4ca6c0aa20ecea642459df33;ac6750ff-272c-4c29-a3f6-80feca312369)
#
# 403 Forbidden: Discussions are disabled for this repo.
# Cannot access content at: https://huggingface.co/api/models/hfl/chinese-roberta-wwm-ext-large/discussions?p=0.
# Make sure your token has the correct permissions.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: hfl/chinese-roberta-wwm-ext-large
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ 最佳模型載入完成
# ==========================================================================================
# Best Model on test_data
# ==========================================================================================
# Loss: 0.4493
# RoBERTa weighted score: 0.7471
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.93      0.93      0.93        83
#           No       0.65      0.65      0.65        17
#
#     accuracy                           0.88       100
#    macro avg       0.79      0.79      0.79       100
# weighted avg       0.88      0.88      0.88       100
#
# Macro F1: 0.7874
# Micro F1: 0.8800
# Accuracy: 0.8800
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.85      0.91      0.88        67
#           No       0.64      0.44      0.52        16
#          N/A       0.76      0.76      0.76        17
#
#     accuracy                           0.81       100
#    macro avg       0.75      0.70      0.72       100
# weighted avg       0.80      0.81      0.80       100
#
# Macro F1: 0.7203
# Micro F1: 0.8100
# Accuracy: 0.8100

# %%
# ============================================================
# Cell 12. 儲存訓練紀錄與測試結果
# ============================================================

final_training_record = {
    "method": "Single RoBERTa for Task 1 and Task 3",
    "description": "RoBERTa only uses the original data field as input. Task 2 and Task 4 will be handled by GPT-4o + RAG few-shot method.",
    "model_name": MODEL_NAME,
    "save_model_path": SAVE_MODEL_PATH,
    "save_split_path": SAVE_SPLIT_PATH,
    "task_fields": TASK_FIELDS,
    "label_lists": LABEL_LISTS,
    "official_weights": OFFICIAL_WEIGHTS,
    "field_weights": FIELD_WEIGHTS,
    "hyperparameters": {
        "max_len": MAX_LEN,
        "batch_size": BATCH_SIZE,
        "accum_steps": ACCUM_STEPS,
        "effective_batch_size": EFFECTIVE_BATCH_SIZE,
        "epochs": EPOCHS,
        "lr": LR,
        "seed": SEED
    },
    "best_model": {
        "best_epoch": best_epoch,
        "best_valid_roberta_score": best_score
    },
    "history": history,
    "test_results": {
        "loss": test_eval["loss"],
        "roberta_score": test_eval["roberta_score"],
        "field_results": {
            field: {
                "macro_f1": test_eval["field_results"][field]["macro_f1"],
                "micro_f1": test_eval["field_results"][field]["micro_f1"],
                "accuracy": test_eval["field_results"][field]["accuracy"]
            }
            for field in TASK_FIELDS
        }
    }
}

with open(SAVE_HISTORY_PATH, "w", encoding="utf-8") as f:
    json.dump(final_training_record, f, ensure_ascii=False, indent=2)

print("✅ 訓練紀錄已儲存：", SAVE_HISTORY_PATH)

print("\n最終摘要：")
print("Best Epoch:", best_epoch)
print("Best Valid RoBERTa Score:", best_score)
print("Test RoBERTa Score:", test_eval["roberta_score"])

for field in TASK_FIELDS:
    print("\n" + field)
    print("Macro F1:", test_eval["field_results"][field]["macro_f1"])
    print("Micro F1:", test_eval["field_results"][field]["micro_f1"])
    print("Accuracy:", test_eval["field_results"][field]["accuracy"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3357/2786982109.py in <cell line: 0>()
#      23     },
#      24     "best_model": {
# ---> 25         "best_epoch": best_epoch,
#      26         "best_valid_roberta_score": best_score
#      27     },
#
# NameError: name 'best_epoch' is not defined

# %%
# ============================================================
# Hybrid Cell 1. 載入切分資料與設定 Hybrid Pipeline 路徑
# ============================================================

import os
import json
import random
import warnings
import numpy as np
import pandas as pd
import torch

from tqdm import tqdm
from google.colab import drive

warnings.filterwarnings("ignore")

# ============================================================
# H1.1 確認 Google Drive
# ============================================================

if not os.path.exists("/content/drive/MyDrive"):
    drive.mount("/content/drive")
else:
    print("✅ Google Drive 已經掛載，不需要重新掛載。")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("使用裝置：", device)

if torch.cuda.is_available():
    print("GPU 名稱：", torch.cuda.get_device_name(0))

# ============================================================
# H1.2 路徑設定
# ============================================================

PROJECT_DIR = "/content/drive/MyDrive/ESG_Project"
MODEL_DIR = "/content/drive/MyDrive/ESG_Models"

SPLIT_PATH = os.path.join(PROJECT_DIR, "task13_train_valid_test_split.json")
ROBERTA_MODEL_PATH = os.path.join(MODEL_DIR, "best_single_roberta_task13.pt")

HYBRID_OUTPUT_PATH = os.path.join(PROJECT_DIR, "hybrid_task1234_predictions.json")
HYBRID_SUBMISSION_PATH = os.path.join(PROJECT_DIR, "hybrid_submission.json")

print("\n路徑設定：")
print("SPLIT_PATH:", SPLIT_PATH)
print("ROBERTA_MODEL_PATH:", ROBERTA_MODEL_PATH)
print("HYBRID_OUTPUT_PATH:", HYBRID_OUTPUT_PATH)
print("HYBRID_SUBMISSION_PATH:", HYBRID_SUBMISSION_PATH)

# ============================================================
# H1.3 檢查檔案是否存在
# ============================================================

if not os.path.exists(SPLIT_PATH):
    raise FileNotFoundError(f"找不到切分資料：{SPLIT_PATH}")

if not os.path.exists(ROBERTA_MODEL_PATH):
    raise FileNotFoundError(f"找不到 RoBERTa 模型：{ROBERTA_MODEL_PATH}")

print("\n✅ split 檔案存在")
print("✅ RoBERTa 模型檔案存在")

# ============================================================
# H1.4 載入切分資料
# ============================================================

with open(SPLIT_PATH, "r", encoding="utf-8") as f:
    split_obj = json.load(f)

train_data = split_obj["train_data"]
valid_data = split_obj["valid_data"]
test_data = split_obj["test_data"]

print("\n資料筆數：")
print("train_data:", len(train_data))
print("valid_data:", len(valid_data))
print("test_data:", len(test_data))

# ============================================================
# H1.5 任務與官方權重
# ============================================================

OFFICIAL_WEIGHTS = {
    "promise_status": 0.20,
    "evidence_status": 0.30,
    "evidence_quality": 0.35,
    "verification_timeline": 0.15
}

ROBERTA_FIELDS = [
    "promise_status",
    "evidence_status"
]

RAG_GPT_FIELDS = [
    "verification_timeline",
    "evidence_quality"
]

ALL_FIELDS = [
    "promise_status",
    "verification_timeline",
    "evidence_status",
    "evidence_quality"
]

LABEL_LISTS_ALL = {
    "promise_status": ["Yes", "No"],
    "verification_timeline": [
        "already",
        "within_2_years",
        "between_2_and_5_years",
        "longer_than_5_years",
        "N/A"
    ],
    "evidence_status": ["Yes", "No", "N/A"],
    "evidence_quality": ["Clear", "Not Clear", "Misleading", "N/A"]
}

print("\nHybrid 任務分配：")
print("RoBERTa:", ROBERTA_FIELDS)
print("GPT-4o + RAG:", RAG_GPT_FIELDS)

# ============================================================
# H1.6 文字輸入格式：照之前，只使用 data
# ============================================================

def clean_text(value):
    if value is None:
        return ""

    value = str(value).strip()

    if value == "":
        return ""

    if value.lower() == "nan":
        return ""

    return value


def get_text(example):
    """
    照之前做法：
    只使用官方原始文本 data。
    """
    data_text = clean_text(example.get("data", ""))

    if data_text:
        return data_text

    raise KeyError(f"找不到 data 欄位，目前 keys = {example.keys()}")

print("\n文字範例：")
print(get_text(test_data[0])[:500])

# ============================================================
# H1.7 檢查 Misleading 是否仍在 test_data
# ============================================================

misleading_in_test = [
    item for item in test_data
    if item.get("evidence_quality") == "Misleading"
]

print("\nMisleading in test_data:", len(misleading_in_test))

if len(misleading_in_test) > 0:
    print("Misleading id:", misleading_in_test[0].get("id"))
# Out:
# ✅ Google Drive 已經掛載，不需要重新掛載。
# 使用裝置： cuda
# GPU 名稱： Tesla T4
#
# 路徑設定：
# SPLIT_PATH: /content/drive/MyDrive/ESG_Project/task13_train_valid_test_split.json
# ROBERTA_MODEL_PATH: /content/drive/MyDrive/ESG_Models/best_single_roberta_task13.pt
# HYBRID_OUTPUT_PATH: /content/drive/MyDrive/ESG_Project/hybrid_task1234_predictions.json
# HYBRID_SUBMISSION_PATH: /content/drive/MyDrive/ESG_Project/hybrid_submission.json
#
# ✅ split 檔案存在
# ✅ RoBERTa 模型檔案存在
#
# 資料筆數：
# train_data: 800
# valid_data: 100
# test_data: 100
#
# Hybrid 任務分配：
# RoBERTa: ['promise_status', 'evidence_status']
# GPT-4o + RAG: ['verification_timeline', 'evidence_quality']
#
# 文字範例：
# 兆豐銀行與兆豐銀行文教基金會長年推動基層體育，持續向下紮根，自 2017 年起兆豐銀行便與美利達展開長期合作，近兩年更提升成為經典百 k 賽事的冠名贊助夥伴，2024 年贊助「兆豐銀行美利達彰化經典百 K」單車賽事活動新臺幣 120 萬元。兆豐銀行董事長雷仲達表示：“兆豐銀行非常鼓勵同仁培養運動習慣，近年組成「兆豐 Mega 車隊」參加經典百 k 賽事，塑造積極向上的企業文化。”
#
# Misleading in test_data: 1
# Misleading id: 10017

# %%
# ============================================================
# Hybrid Cell 2. 載入 RoBERTa 並預測 Task 1、Task 3
# ============================================================

import torch.nn as nn
from transformers import AutoModel, AutoTokenizer
from sklearn.metrics import classification_report, f1_score, accuracy_score

# ============================================================
# H2.1 載入 checkpoint
# ============================================================

checkpoint = torch.load(ROBERTA_MODEL_PATH, map_location=device)

MODEL_NAME = checkpoint["model_name"]
TASK_FIELDS = checkpoint["task_fields"]
LABEL_LISTS = checkpoint["label_lists"]
label2id = checkpoint["label2id"]
id2label = checkpoint["id2label"]
num_labels_dict = checkpoint["num_labels_dict"]
MAX_LEN = checkpoint["max_len"]

print("載入 RoBERTa checkpoint：")
print("MODEL_NAME:", MODEL_NAME)
print("TASK_FIELDS:", TASK_FIELDS)
print("Best Epoch:", checkpoint["best_epoch"])
print("Best Valid Score:", checkpoint["best_score"])

# ============================================================
# H2.2 定義模型結構
# 必須跟訓練時一樣
# ============================================================

class SingleRoBERTaTask13(nn.Module):
    def __init__(self, model_name, num_labels_dict, dropout_rate=0.1):
        super().__init__()

        self.roberta = AutoModel.from_pretrained(model_name)
        self.roberta.gradient_checkpointing_enable()

        hidden_size = self.roberta.config.hidden_size

        self.dropout = nn.Dropout(dropout_rate)

        self.classifiers = nn.ModuleDict({
            field: nn.Linear(hidden_size, num_labels_dict[field])
            for field in TASK_FIELDS
        })

        for classifier in self.classifiers.values():
            nn.init.normal_(classifier.weight, std=0.02)
            nn.init.zeros_(classifier.bias)

    def forward(self, input_ids, attention_mask):
        outputs = self.roberta(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        cls_output = outputs.last_hidden_state[:, 0, :]
        cls_output = self.dropout(cls_output)

        logits = {
            field: self.classifiers[field](cls_output)
            for field in TASK_FIELDS
        }

        return logits

# ============================================================
# H2.3 載入 tokenizer 與模型
# ============================================================

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

roberta_model = SingleRoBERTaTask13(
    model_name=MODEL_NAME,
    num_labels_dict=num_labels_dict,
    dropout_rate=0.1
)

roberta_model.load_state_dict(checkpoint["model_state_dict"])
roberta_model.to(device)
roberta_model.eval()

print("\n✅ RoBERTa 模型載入完成")

# ============================================================
# H2.4 單筆預測函數
# ============================================================

def roberta_predict_one(text):
    encoding = tokenizer(
        text,
        truncation=True,
        padding="max_length",
        max_length=MAX_LEN,
        return_tensors="pt"
    )

    input_ids = encoding["input_ids"].to(device)
    attention_mask = encoding["attention_mask"].to(device)

    with torch.no_grad():
        logits = roberta_model(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

    pred = {}

    for field in TASK_FIELDS:
        pred_id = torch.argmax(logits[field], dim=1).item()
        pred[field] = id2label[field][pred_id]

    return pred

# ============================================================
# H2.5 對 test_data 預測 Task 1、Task 3
# ============================================================

roberta_predictions = []

for item in tqdm(test_data, desc="RoBERTa predicting Task 1 & 3"):
    text = get_text(item)
    pred = roberta_predict_one(text)

    roberta_predictions.append({
        "id": item.get("id"),
        "promise_status": pred["promise_status"],
        "evidence_status": pred["evidence_status"]
    })

print("\n✅ RoBERTa 預測完成")
print("預測筆數：", len(roberta_predictions))
print("第一筆預測：")
print(roberta_predictions[0])

# ============================================================
# H2.6 評估 RoBERTa 在 test_data 的 Task 1、Task 3 表現
# ============================================================

print("\n" + "=" * 90)
print("RoBERTa Test Evaluation for Task 1 and Task 3")
print("=" * 90)

roberta_eval_results = {}

for field in TASK_FIELDS:
    y_true = [item[field] for item in test_data]
    y_pred = [pred[field] for pred in roberta_predictions]

    labels = LABEL_LISTS[field]

    print("\n" + "=" * 70)
    print(field)
    print("=" * 70)

    print(classification_report(
        y_true,
        y_pred,
        labels=labels,
        zero_division=0
    ))

    macro_f1 = f1_score(
        y_true,
        y_pred,
        labels=labels,
        average="macro",
        zero_division=0
    )

    micro_f1 = f1_score(
        y_true,
        y_pred,
        labels=labels,
        average="micro",
        zero_division=0
    )

    acc = accuracy_score(y_true, y_pred)

    roberta_eval_results[field] = {
        "macro_f1": macro_f1,
        "micro_f1": micro_f1,
        "accuracy": acc
    }

    print(f"Macro F1: {macro_f1:.4f}")
    print(f"Micro F1: {micro_f1:.4f}")
    print(f"Accuracy: {acc:.4f}")

roberta_weighted_score = (
    roberta_eval_results["promise_status"]["macro_f1"] * OFFICIAL_WEIGHTS["promise_status"]
    + roberta_eval_results["evidence_status"]["macro_f1"] * OFFICIAL_WEIGHTS["evidence_status"]
) / (
    OFFICIAL_WEIGHTS["promise_status"]
    + OFFICIAL_WEIGHTS["evidence_status"]
)

print("\nRoBERTa weighted score:", roberta_weighted_score)
# Out:
# 載入 RoBERTa checkpoint：
# MODEL_NAME: hfl/chinese-roberta-wwm-ext-large
# TASK_FIELDS: ['promise_status', 'evidence_status']
# Best Epoch: 5
# Best Valid Score: 0.6360101420822484
# Exception in thread Thread-auto_conversion:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 761, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/httpx/_models.py", line 829, in raise_for_status
#     raise HTTPStatusError(message, request=request, response=self)
# httpx.HTTPStatusError: Client error '403 Forbidden' for url 'https://huggingface.co/api/models/hfl/chinese-roberta-wwm-ext-large/discussions?p=0'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 116, in auto_conversion
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 95, in auto_conversion
#     sha = get_conversion_pr_reference(api, pretrained_model_name_or_path, **cached_file_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 68, in get_conversion_pr_reference
#     pr = previous_pr(api, model_id, pr_title, token=token)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/safetensors_conversion.py", line 14, in previous_pr
#     for discussion in get_repo_discussions(repo_id=model_id, token=token):
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 6949, in get_repo_discussions
#     discussions, has_next = _fetch_discussion_page(page_index=page_index)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hf_api.py", line 6938, in _fetch_discussion_page
#     hf_raise_for_status(resp)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 849, in hf_raise_for_status
#     raise _format(HfHubHTTPError, message, response) from e
# huggingface_hub.errors.HfHubHTTPError: (Request ID: Root=1-69fc4e78-49a2b9f536f12cd53ea35616;90022958-36be-4d25-a4d2-56654dded2d4)
#
# 403 Forbidden: Discussions are disabled for this repo.
# Cannot access content at: https://huggingface.co/api/models/hfl/chinese-roberta-wwm-ext-large/discussions?p=0.
# Make sure your token has the correct permissions.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: hfl/chinese-roberta-wwm-ext-large
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ RoBERTa 模型載入完成
# RoBERTa predicting Task 1 & 3: 100%|██████████| 100/100 [00:09<00:00, 10.89it/s]
# ✅ RoBERTa 預測完成
# 預測筆數： 100
# 第一筆預測：
# {'id': 10939, 'promise_status': 'Yes', 'evidence_status': 'Yes'}
#
# ==========================================================================================
# RoBERTa Test Evaluation for Task 1 and Task 3
# ==========================================================================================
#
# ======================================================================
# promise_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.93      0.93      0.93        83
#           No       0.65      0.65      0.65        17
#
#     accuracy                           0.88       100
#    macro avg       0.79      0.79      0.79       100
# weighted avg       0.88      0.88      0.88       100
#
# Macro F1: 0.7874
# Micro F1: 0.8800
# Accuracy: 0.8800
#
# ======================================================================
# evidence_status
# ======================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.85      0.91      0.88        67
#           No       0.64      0.44      0.52        16
#          N/A       0.76      0.76      0.76        17
#
#     accuracy                           0.81       100
#    macro avg       0.75      0.70      0.72       100
# weighted avg       0.80      0.81      0.80       100
#
# Macro F1: 0.7203
# Micro F1: 0.8100
# Accuracy: 0.8100
#
# RoBERTa weighted score: 0.7471383819001968

# %%
# ============================================================
# Hybrid Cell 3. 建立 RAG Retrieval Pool
# 用 train_data + valid_data 作為 few-shot 檢索資料庫
# ============================================================

from collections import Counter

# ============================================================
# H3.1 建立 retrieval pool
# ============================================================

retrieval_source_data = train_data + valid_data

retrieval_pool = []

for item in retrieval_source_data:
    record = {
        "id": item.get("id"),
        "text": get_text(item),
        "verification_timeline": item.get("verification_timeline"),
        "evidence_quality": item.get("evidence_quality"),
        "promise_status": item.get("promise_status"),
        "evidence_status": item.get("evidence_status")
    }

    retrieval_pool.append(record)

print("retrieval_pool 筆數：", len(retrieval_pool))

# ============================================================
# H3.2 檢查 retrieval pool 不包含 Misleading
# ============================================================

retrieval_misleading = [
    item for item in retrieval_pool
    if item.get("evidence_quality") == "Misleading"
]

print("retrieval_pool Misleading 筆數：", len(retrieval_misleading))

if len(retrieval_misleading) > 0:
    print("⚠️ retrieval_pool 含 Misleading，請檢查是否外洩")
    print(retrieval_misleading[0])
else:
    print("✅ retrieval_pool 不含 Misleading，沒有把 test 的 Misleading 放進檢索庫")

# ============================================================
# H3.3 檢查 RAG 任務標籤分布
# ============================================================

print("\nretrieval_pool verification_timeline 分布：")
vt_counter = Counter([item["verification_timeline"] for item in retrieval_pool])
for label, count in vt_counter.items():
    print(f"{label}: {count}")

print("\nretrieval_pool evidence_quality 分布：")
eq_counter = Counter([item["evidence_quality"] for item in retrieval_pool])
for label, count in eq_counter.items():
    print(f"{label}: {count}")

# ============================================================
# H3.4 查看 retrieval 範例
# ============================================================

print("\nretrieval_pool 第一筆範例：")
print("id:", retrieval_pool[0]["id"])
print("verification_timeline:", retrieval_pool[0]["verification_timeline"])
print("evidence_quality:", retrieval_pool[0]["evidence_quality"])
print("text:", retrieval_pool[0]["text"][:500])
# Out:
# retrieval_pool 筆數： 900
# retrieval_pool Misleading 筆數： 0
# ✅ retrieval_pool 不含 Misleading，沒有把 test 的 Misleading 放進檢索庫
#
# retrieval_pool verification_timeline 分布：
# already: 328
# between_2_and_5_years: 212
# N/A: 169
# longer_than_5_years: 179
# within_2_years: 12
#
# retrieval_pool evidence_quality 分布：
# Clear: 497
# N/A: 290
# Not Clear: 113
#
# retrieval_pool 第一筆範例：
# id: 10751
# verification_timeline: already
# evidence_quality: Clear
# text: 為提升身心障礙者取得申貸服務的可及性與便利性，針對身障客戶提供簽約對保到府服務，同時規畫無障礙網頁，於2024年第一季上線運作。身心障礙者友善環境在中租控股之辦公室環境評估中列為重要項目，以內湖總公司為示範，大樓入口設有方便身心障礙者出入之無障礙坡道，且設置警衛亭，以人力因應第一時間提供需協助之身心障礙者。配合身心障礙者權益保障法規規定，導盲犬、導聾犬及肢體輔導犬等得自由出入各營業單位。中租控股所承租的分公司大樓內部每層樓皆設有無障礙廁所，總數多達78間，達到友善環境之落實。針對台灣各地區分公司辦公室，也盡力挑選對身心障礙同仁友善之辦公大樓，打造無障礙的友善工作空間，以求軟硬體上的兼顧，皆能友善地服務身心障礙者。

# %%
# ============================================================
# Hybrid Cell 4. 建立 Embedding 與 Top-K 檢索函數
# ============================================================

# !pip install -q sentence-transformers

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# ============================================================
# H4.1 載入 Multilingual E5 Embedding 模型
# ============================================================

EMBEDDING_MODEL_NAME = "intfloat/multilingual-e5-base"

print("載入 embedding model：", EMBEDDING_MODEL_NAME)

embedder = SentenceTransformer(
    EMBEDDING_MODEL_NAME,
    device=str(device)
)

# ============================================================
# H4.2 E5 輸入格式
# E5 建議 passage 用 passage:，query 用 query:
# ============================================================

def e5_passage(text):
    return "passage: " + clean_text(text)

def e5_query(text):
    return "query: " + clean_text(text)

# ============================================================
# H4.3 建立 retrieval embeddings
# ============================================================

retrieval_texts = [
    e5_passage(item["text"])
    for item in retrieval_pool
]

print("開始建立 retrieval embeddings...")
print("retrieval_texts 筆數：", len(retrieval_texts))

retrieval_embeddings = embedder.encode(
    retrieval_texts,
    batch_size=16,
    show_progress_bar=True,
    normalize_embeddings=True
)

print("✅ retrieval embeddings 建立完成")
print("retrieval_embeddings shape:", retrieval_embeddings.shape)

# ============================================================
# H4.4 Top-K 檢索函數
# ============================================================

TOP_K = 6

def retrieve_top_k_examples(query_text, top_k=TOP_K):
    query_embedding = embedder.encode(
        [e5_query(query_text)],
        normalize_embeddings=True
    )

    scores = cosine_similarity(
        query_embedding,
        retrieval_embeddings
    )[0]

    top_indices = np.argsort(scores)[::-1][:top_k]

    examples = []

    for idx in top_indices:
        example = retrieval_pool[idx].copy()
        example["similarity_score"] = float(scores[idx])
        examples.append(example)

    return examples

# ============================================================
# H4.5 測試檢索一筆 test_data
# ============================================================

sample_item = test_data[0]
sample_text = get_text(sample_item)

sample_examples = retrieve_top_k_examples(sample_text, top_k=TOP_K)

print("\n測試檢索：")
print("test id:", sample_item.get("id"))
print("test verification_timeline:", sample_item.get("verification_timeline"))
print("test evidence_quality:", sample_item.get("evidence_quality"))
print("test text:", sample_text[:300])

for i, ex in enumerate(sample_examples, 1):
    print("\n" + "-" * 80)
    print(f"Top {i} | score = {ex['similarity_score']:.4f}")
    print("id:", ex["id"])
    print("verification_timeline:", ex["verification_timeline"])
    print("evidence_quality:", ex["evidence_quality"])
    print("text:", ex["text"][:300])
# Out:
# 載入 embedding model： intfloat/multilingual-e5-base
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# XLMRobertaModel LOAD REPORT from: intfloat/multilingual-e5-base
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 開始建立 retrieval embeddings...
# retrieval_texts 筆數： 900
# Batches:   0%|          | 0/57 [00:00<?, ?it/s]
# ✅ retrieval embeddings 建立完成
# retrieval_embeddings shape: (900, 768)
#
# 測試檢索：
# test id: 10939
# test verification_timeline: already
# test evidence_quality: Clear
# test text: 兆豐銀行與兆豐銀行文教基金會長年推動基層體育，持續向下紮根，自 2017 年起兆豐銀行便與美利達展開長期合作，近兩年更提升成為經典百 k 賽事的冠名贊助夥伴，2024 年贊助「兆豐銀行美利達彰化經典百 K」單車賽事活動新臺幣 120 萬元。兆豐銀行董事長雷仲達表示：“兆豐銀行非常鼓勵同仁培養運動習慣，近年組成「兆豐 Mega 車隊」參加經典百 k 賽事，塑造積極向上的企業文化。”
#
# --------------------------------------------------------------------------------
# Top 1 | score = 0.8717
# id: 10246
# verification_timeline: already
# evidence_quality: Clear
# text: 為幫助國內家庭經濟困難及高風險家庭的學生，本公司持續攜手富邦慈善基金會、串聯富邦悍將隊，執行體育公益回饋創新專案–「悍」你用愛心做朋友，球季期間，富邦悍將隊於新莊主場賽事每得 1 分，本公司即捐贈新北在地弱勢學子 1 年 7,200 元的助學金。2024 年共捐助新臺幣約 164 萬元，幫助 228 位弱勢學童，盼望陪伴更多孩子安心學習成長，並勉勵遭遇到人生各種挫折與挑戰時，展現奮戰不懈的運動家精神。
#
# --------------------------------------------------------------------------------
# Top 2 | score = 0.8712
# id: 10849
# verification_timeline: already
# evidence_quality: Clear
# text: 世芯電子以促進文化與教育發展為己任，積極投入資源於學校體育與人才培育，2024 年贊助臺灣科技大學籃球隊，設立球員獎學金計畫，總額高達新臺幣 28 萬元，專為 14 名球員提供每人每學年新臺幣 20,000 元的獎學金。此計畫旨在鼓勵球員平衡學業與運動表現，激勵學生追求卓越，並透過實際行動支持年輕學子在學術與運動領域雙軌並進，培養未來社會所需的多**元人才**。
#
# --------------------------------------------------------------------------------
# Top 3 | score = 0.8711
# id: 10901
# verification_timeline: already
# evidence_quality: Clear
# text: 兆豐保險自 2021 年起每年持續與臺灣山林復育協會合作在地原生林植樹活動，至今已累積種植逾 400 顆在地原生植物種。今年適逢公司成立 93 周年，特別加辦在地原生復育暨構樹造紙親子活動，並擴大邀請員工及眷屬一同參與。有別以往單純的復育植樹，本次活動帶入樹木生命週期的概念，從隨處可見的當地構樹特性解說，至帶領親子體驗構樹木造紙的過程，大手牽小手共同進行苗木換盆並種下樹苗。希望藉由兆豐員工的親自參與，為愛護環境盡一份心力，更將綠色生活的概念傳給下一代、向下紮根。
#
# --------------------------------------------------------------------------------
# Top 4 | score = 0.8670
# id: 10753
# verification_timeline: already
# evidence_quality: Clear
# text: 兆豐集團以創造金融業全方位正向影響力為使命，除了促進經濟發展，亦期許自己發揮金融業職能，以「促進社會共榮」為社會面的永續策略，兆豐依據社區之風險或機會進行分析評估後，於 2024 年底更新集團社會共榮主軸，分別為「金融教育」、「弱勢關懷」、「文化傳承」、「生態永續」四大社會共榮主軸，同時回應聯合國永續發展目標 (Sustainable Development Goals, SDGs)，發揮正向影響力。2024 年兆豐銀行及保險蟬聯「保險信望愛獎 - 最佳社會責任獎」優選獎，社會共榮成果備受各界肯定。
#
# --------------------------------------------------------------------------------
# Top 5 | score = 0.8642
# id: 10107
# verification_timeline: longer_than_5_years
# evidence_quality: Clear
# text: 4 大公益策略 2026-2030 年目標    樂在學習  • 至 2030 年合庫銀行研究獎金及獎助學金頒發約 1,073 萬元，鼓勵學生對金融創新、綠色金融、資訊安全、金融科技及 ESG 等議題深入研究，為金融業帶入創新思維。  • 持續辦理合庫講堂、普惠金融相關講座及論壇，至 2030 年辦理逾 2,200 場，包括赴社福團體、醫療機構、學校及安養機構辦理跨產業信託講習，提升民眾信託觀念，另透過理財講座及客戶說明會，使更多民眾認識合庫集團之金融商品，提早規劃樂活安養生活。  • 至 2030 年合庫銀行舉辦理財育樂營共 5 場，向學童宣導理財之重要性及建立財務規劃觀念。  • 至 20
#
# --------------------------------------------------------------------------------
# Top 6 | score = 0.8640
# id: 10463
# verification_timeline: already
# evidence_quality: Clear
# text: 國泰世華銀行於 2009 年首創「職棒球員防賭基金信託」與「職棒聯盟球員退休儲蓄機制」，保障球員財務安全並提升台灣職棒環境。信託期間，球員若需提領資金，須經工會同意後銀行才會撥款，確保資金運用合規，退役後則全數返還，保障其生活品質。此外，已連續 12 年攜手職棒球員工會推動「職棒工會回饋列車」，走訪百餘所機關學校，與少棒選手互動交流。2024 年度「職棒球員防賭基金信託」財產本金達新台幣 1.74 億元。

# %%
# ============================================================
# Hybrid Cell 11. 建立雙 Prompt v3
# Timeline prompt v3 + Quality prompt v3
# ============================================================

# ============================================================
# 11.1 合法標籤
# ============================================================

VALID_VERIFICATION_TIMELINE = [
    "already",
    "within_2_years",
    "between_2_and_5_years",
    "longer_than_5_years",
    "N/A"
]

VALID_EVIDENCE_QUALITY = [
    "Clear",
    "Not Clear",
    "Misleading",
    "N/A"
]

# ============================================================
# 11.2 確認 RoBERTa prediction by id
# ============================================================

roberta_pred_by_id = {
    item["id"]: item
    for item in roberta_predictions
}

print("RoBERTa predictions 筆數：", len(roberta_pred_by_id))

# ============================================================
# 11.3 Timeline 專用 Prompt v3
# ============================================================

def build_timeline_prompt_v3(test_text, retrieved_examples, roberta_pred):
    """
    Timeline prompt v3:
    只預測 verification_timeline。
    不預測 evidence_quality。
    """

    examples_text = ""

    for i, ex in enumerate(retrieved_examples, 1):
        examples_text += f"""
【相似範例 {i}】
文本：
{ex["text"]}

標籤：
verification_timeline = {ex["verification_timeline"]}
promise_status = {ex["promise_status"]}
evidence_status = {ex["evidence_status"]}
"""

    prompt = f"""
你是一位嚴謹的 ESG Promise Verification 標註專家。
請根據測試文本、RoBERTa 輔助預測、標籤定義與相似範例，只判斷 verification_timeline。

你只需要預測：
1. verification_timeline

請不要預測 promise_status。
請不要預測 evidence_status。
請不要預測 evidence_quality。
請只輸出 JSON。

============================================================
RoBERTa 輔助預測
============================================================

promise_status = {roberta_pred["promise_status"]}
evidence_status = {roberta_pred["evidence_status"]}

注意：
- RoBERTa 預測只是輔助，不一定完全正確。
- verification_timeline 主要看「承諾或行動的時間狀態」。
- 不要只因為文本出現 2024 年就一定判 already。
- 不要只因為文本出現「持續」就一定判 already。
- 要判斷文本重點是在「已完成事實」還是「未來承諾/後續目標」。

============================================================
verification_timeline 標籤定義
============================================================

- already：
文本主要描述 ESG 行動、成果、制度、活動、認證、揭露、調查、稽核或數據已經發生、已經存在、已經完成。
常見線索：
「已完成」、「已取得」、「已通過」、「已達成」、「已執行」、「已設立」、
「於 2024 年完成」、「2024 年共...」、「累計...」、「已累積...」、「自某年起已持續...」。

- within_2_years：
文本明確表示某項承諾、目標或行動會在 2 年內完成。
只有明確短期期限時才使用，例如：
「一年內」、「兩年內」、「2025 年前」、「2026 年前」。
如果沒有明確短期完成期限，不要亂判 within_2_years。

- between_2_and_5_years：
文本描述未來承諾、後續追蹤、逐步推動、持續改善、持續優化、階段性推動，且不像是超長期目標。
常見線索：
「將持續」、「後續追蹤」、「持續改善」、「持續優化」、「持續精進」、
「逐步建立」、「逐步推動」、「規劃」、「訂定目標」、「階段性推動」、
「期待」、「期盼」、「共同推動」、「未來將...」。
注意：即使文本前面有已完成成果，只要重點落在後續追蹤或未來推動，也可能是 between_2_and_5_years。

- longer_than_5_years：
文本明確描述長期承諾或長期目標。
常見線索：
「長期目標」、「中長期目標」、「短中長期目標」、
「2030」、「2040」、「2050」、「淨零」、「碳中和」。
注意：「長年」、「長期合作」如果只是描述過去長期合作，不一定是 longer_than_5_years，可能是 already。

- N/A：
文本沒有明確時間資訊，或只是描述治理架構、組織職責、委員會、管理流程、政策原則，沒有可判斷的承諾時間。
常見線索：
「委員會」、「執行小組」、「治理架構」、「管理架構」、「政策制定」、
「統籌推動」、「負責執行」、「最高督導單位」。
但如果這些文本同時有明確已完成成果或未來目標，仍要依內容判斷 already / future label。

============================================================
重要判斷規則 v3
============================================================

1. 先判斷文本重點：
   - 主要是已發生事實 → already
   - 主要是未來目標、後續追蹤、階段性推動 → between_2_and_5_years 或 longer_than_5_years
   - 主要是治理架構或職責描述，沒有時間承諾 → N/A

2. 如果同時有「已完成事實」和「未來持續追蹤」：
   - 若後續追蹤/未來推動是文本重點，偏 between_2_and_5_years。
   - 若未來只是附帶描述，主體是已完成成果，偏 already。

3. 「2030 / 2040 / 2050 / 淨零 / 碳中和」通常表示 longer_than_5_years。
4. 「短、中、長期目標」通常表示 longer_than_5_years。
5. 「長年合作」「長期合作」描述過去合作關係時，不等於 longer_than_5_years。
6. 沒有明確時間或承諾時間時，不要硬猜，判 N/A。

============================================================
相似範例
============================================================

{examples_text}

============================================================
測試文本
============================================================

{test_text}

============================================================
輸出格式
============================================================

請只輸出以下 JSON 格式，不要加入 markdown，不要加入說明文字：

{{
  "verification_timeline": "already"
}}
"""

    return prompt

# ============================================================
# 11.4 Evidence Quality 專用 Prompt v3
# ============================================================

def build_quality_prompt_v3(test_text, retrieved_examples, roberta_pred):
    """
    Quality prompt v3:
    只預測 evidence_quality。
    不預測 verification_timeline。
    """

    examples_text = ""

    for i, ex in enumerate(retrieved_examples, 1):
        examples_text += f"""
【相似範例 {i}】
文本：
{ex["text"]}

標籤：
promise_status = {ex["promise_status"]}
evidence_status = {ex["evidence_status"]}
evidence_quality = {ex["evidence_quality"]}
"""

    prompt = f"""
你是一位嚴謹的 ESG Promise Verification 標註專家。
請根據測試文本、RoBERTa 輔助預測、標籤定義與相似範例，只判斷 evidence_quality。

你只需要預測：
1. evidence_quality

請不要預測 verification_timeline。
請不要預測 promise_status。
請不要預測 evidence_status。
請只輸出 JSON。

============================================================
RoBERTa 輔助預測
============================================================

promise_status = {roberta_pred["promise_status"]}
evidence_status = {roberta_pred["evidence_status"]}

注意：
- RoBERTa 預測只是輔助，不一定完全正確。
- evidence_status 對 evidence_quality 很重要。
- 如果 evidence_status = N/A，通常 evidence_quality = N/A。
- 如果 evidence_status = No，通常 evidence_quality = N/A。
- 但如果文本明顯使用 ESG 正面語氣、治理語氣或承諾語氣，卻沒有具體證據，可能是 Not Clear 或 Misleading。

============================================================
evidence_quality 標籤定義
============================================================

- Clear：
文本提供具體、可驗證的證據。
常見證據包括：
明確年份、金額、百分比、數量、人次、件數、場次、第三方驗證、ISO 認證、SBTi、獎項、具體成果、量化指標、已完成成果、達成率、改善率、投入金額、捐助金額。

- Not Clear：
文本有 ESG 承諾、方向、政策、制度、行動或管理描述，但證據不足、不夠具體。
常見情況：
只有「致力於」、「持續推動」、「強化」、「提升」、「落實」、「重視」、「改善」、「遵循」等方向性語句，
但缺少可驗證數據、具體成果、明確認證、量化指標。

- Misleading：
文本使用很正式、正面、承諾式、治理式或社會責任語氣，使讀者可能誤以為公司已有明確 ESG 作為、證據或驗證，
但實際上沒有具體數據、沒有驗證依據、沒有明確成果、沒有可查證證據。
Misleading 比 Not Clear 更像「過度包裝」或「容易讓人誤解已有證據」。
常見語氣：
「致力於穩健經營」、「確保持續成長」、「兼顧股東權益、員工發展與社會責任」、
「提升企業競爭力」、「承諾遵循法規」、「維持高標準透明度與公司治理」。
如果整段文字多是漂亮口號與治理承諾，但沒有具體數字、年份、認證、成果，請考慮 Misleading。

- N/A：
文本不適用 evidence_quality 判斷。
常見情況：
沒有 evidence、沒有 promise，或主要是背景介紹、組織架構、管理職責、政策描述，且不構成可評估的證據品質。

============================================================
重要判斷規則 v3
============================================================

1. 如果 evidence_status = Yes：
   - 有具體數據、年份、金額、百分比、認證、獎項、量化成果 → Clear
   - 只有方向性描述或制度性描述，缺乏可驗證成果 → Not Clear
   - 語氣很正面、很像 ESG 成果，但沒有具體證據 → Misleading

2. 如果 evidence_status = No 或 N/A：
   - 通常 evidence_quality = N/A
   - 但如果文本有強烈 ESG 口號式承諾、治理包裝、社會責任語氣，且缺乏證據 → Misleading 或 Not Clear

3. 不要因為文本有「2024 年」就自動判 Clear。
   要看 2024 年是否連結到具體成果、數據、認證、活動或量化證據。

4. 不要因為文本很正式、很像永續報告就自動判 Clear。
   如果沒有具體可驗證內容，應判 Not Clear 或 Misleading。

5. 如果文本有明確量化證據，例如「120 萬元」、「228 位」、「93.4%」、「1.74 億元」、「ISO 27001」、「SBTi 通過」，通常判 Clear。

6. Misleading 只在文本明顯有過度正面包裝、承諾式語氣，且缺乏具體證據時使用。
   如果只是一般證據不足，判 Not Clear。

============================================================
相似範例
============================================================

{examples_text}

============================================================
測試文本
============================================================

{test_text}

============================================================
輸出格式
============================================================

請只輸出以下 JSON 格式，不要加入 markdown，不要加入說明文字：

{{
  "evidence_quality": "Clear"
}}
"""

    return prompt

# ============================================================
# 11.5 測試建立 prompt
# ============================================================

sample_item = test_data[0]
sample_text = get_text(sample_item)
sample_examples = retrieve_top_k_examples(sample_text, top_k=TOP_K)
sample_roberta_pred = roberta_pred_by_id[sample_item["id"]]

sample_timeline_prompt_v3 = build_timeline_prompt_v3(
    test_text=sample_text,
    retrieved_examples=sample_examples,
    roberta_pred=sample_roberta_pred
)

sample_quality_prompt_v3 = build_quality_prompt_v3(
    test_text=sample_text,
    retrieved_examples=sample_examples,
    roberta_pred=sample_roberta_pred
)

print("Timeline Prompt v3 長度:", len(sample_timeline_prompt_v3))
print("Quality Prompt v3 長度:", len(sample_quality_prompt_v3))

print("\nTimeline Prompt v3 前 2000 字：")
print(sample_timeline_prompt_v3[:2000])

print("\n" + "=" * 80)
print("Quality Prompt v3 前 2000 字：")
print(sample_quality_prompt_v3[:2000])
# Out:
# RoBERTa predictions 筆數： 100
# Timeline Prompt v3 長度: 4849
# Quality Prompt v3 長度: 4775
#
# Timeline Prompt v3 前 2000 字：
#
# 你是一位嚴謹的 ESG Promise Verification 標註專家。
# 請根據測試文本、RoBERTa 輔助預測、標籤定義與相似範例，只判斷 verification_timeline。
#
# 你只需要預測：
# 1. verification_timeline
#
# 請不要預測 promise_status。
# 請不要預測 evidence_status。
# 請不要預測 evidence_quality。
# 請只輸出 JSON。
#
# ============================================================
# RoBERTa 輔助預測
# ============================================================
#
# promise_status = Yes
# evidence_status = Yes
#
# 注意：
# - RoBERTa 預測只是輔助，不一定完全正確。
# - verification_timeline 主要看「承諾或行動的時間狀態」。
# - 不要只因為文本出現 2024 年就一定判 already。
# - 不要只因為文本出現「持續」就一定判 already。
# - 要判斷文本重點是在「已完成事實」還是「未來承諾/後續目標」。
#
# ============================================================
# verification_timeline 標籤定義
# ============================================================
#
# - already：
# 文本主要描述 ESG 行動、成果、制度、活動、認證、揭露、調查、稽核或數據已經發生、已經存在、已經完成。
# 常見線索：
# 「已完成」、「已取得」、「已通過」、「已達成」、「已執行」、「已設立」、
# 「於 2024 年完成」、「2024 年共...」、「累計...」、「已累積...」、「自某年起已持續...」。
#
# - within_2_years：
# 文本明確表示某項承諾、目標或行動會在 2 年內完成。
# 只有明確短期期限時才使用，例如：
# 「一年內」、「兩年內」、「2025 年前」、「2026 年前」。
# 如果沒有明確短期完成期限，不要亂判 within_2_years。
#
# - between_2_and_5_years：
# 文本描述未來承諾、後續追蹤、逐步推動、持續改善、持續優化、階段性推動，且不像是超長期目標。
# 常見線索：
# 「將持續」、「後續追蹤」、「持續改善」、「持續優化」、「持續精進」、
# 「逐步建立」、「逐步推動」、「規劃」、「訂定目標」、「階段性推動」、
# 「期待」、「期盼」、「共同推動」、「未來將...」。
# 注意：即使文本前面有已完成成果，只要重點落在後續追蹤或未來推動，也可能是 between_2_and_5_years。
#
# - longer_than_5_years：
# 文本明確描述長期承諾或長期目標。
# 常見線索：
# 「長期目標」、「中長期目標」、「短中長期目標」、
# 「2030」、「2040」、「2050」、「淨零」、「碳中和」。
# 注意：「長年」、「長期合作」如果只是描述過去長期合作，不一定是 longer_than_5_years，可能是 already。
#
# - N/A：
# 文本沒有明確時間資訊，或只是描述治理架構、組織職責、委員會、管理流程、政策原則，沒有可判斷的承諾時間。
# 常見線索：
# 「委員會」、「執行小組」、「治理架構」、「管理架構」、「政策制定」、
# 「統籌推動」、「負責執行」、「最高督導單位」。
# 但如果這些文本同時有明確已完成成果或未來目標，仍要依內容判斷 already / future label。
#
# ============================================================
# 重要判斷規則 v3
# ============================================================
#
# 1. 先判斷文本重點：
#    - 主要是已發生事實 → already
#    - 主要是未來目標、後續追蹤、階段性推動 → between_2_and_5_years 或 longer_than_5_years
#    - 主要是治理架構或職責描述，沒有時間承諾 → N/A
#
# 2. 如果同時有「已完成事實」和「未來持續追蹤」：
#    - 若後續追蹤/未來推動是文本重點，偏 between_2_and_5_years。
#    - 若未來只是附帶描述，主體是已完成成果，偏 already。
#
# 3. 「2030 / 2040 / 2050 / 淨零 / 碳
#
# ================================================================================
# Quality Prompt v3 前 2000 字：
#
# 你是一位嚴謹的 ESG Promise Verification 標註專家。
# 請根據測試文本、RoBERTa 輔助預測、標籤定義與相似範例，只判斷 evidence_quality。
#
# 你只需要預測：
# 1. evidence_quality
#
# 請不要預測 verification_timeline。
# 請不要預測 promise_status。
# 請不要預測 evidence_status。
# 請只輸出 JSON。
#
# ============================================================
# RoBERTa 輔助預測
# ============================================================
#
# promise_status = Yes
# evidence_status = Yes
#
# 注意：
# - RoBERTa 預測只是輔助，不一定完全正確。
# - evidence_status 對 evidence_quality 很重要。
# - 如果 evidence_status = N/A，通常 evidence_quality = N/A。
# - 如果 evidence_status = No，通常 evidence_quality = N/A。
# - 但如果文本明顯使用 ESG 正面語氣、治理語氣或承諾語氣，卻沒有具體證據，可能是 Not Clear 或 Misleading。
#
# ============================================================
# evidence_quality 標籤定義
# ============================================================
#
# - Clear：
# 文本提供具體、可驗證的證據。
# 常見證據包括：
# 明確年份、金額、百分比、數量、人次、件數、場次、第三方驗證、ISO 認證、SBTi、獎項、具體成果、量化指標、已完成成果、達成率、改善率、投入金額、捐助金額。
#
# - Not Clear：
# 文本有 ESG 承諾、方向、政策、制度、行動或管理描述，但證據不足、不夠具體。
# 常見情況：
# 只有「致力於」、「持續推動」、「強化」、「提升」、「落實」、「重視」、「改善」、「遵循」等方向性語句，
# 但缺少可驗證數據、具體成果、明確認證、量化指標。
#
# - Misleading：
# 文本使用很正式、正面、承諾式、治理式或社會責任語氣，使讀者可能誤以為公司已有明確 ESG 作為、證據或驗證，
# 但實際上沒有具體數據、沒有驗證依據、沒有明確成果、沒有可查證證據。
# Misleading 比 Not Clear 更像「過度包裝」或「容易讓人誤解已有證據」。
# 常見語氣：
# 「致力於穩健經營」、「確保持續成長」、「兼顧股東權益、員工發展與社會責任」、
# 「提升企業競爭力」、「承諾遵循法規」、「維持高標準透明度與公司治理」。
# 如果整段文字多是漂亮口號與治理承諾，但沒有具體數字、年份、認證、成果，請考慮 Misleading。
#
# - N/A：
# 文本不適用 evidence_quality 判斷。
# 常見情況：
# 沒有 evidence、沒有 promise，或主要是背景介紹、組織架構、管理職責、政策描述，且不構成可評估的證據品質。
#
# ============================================================
# 重要判斷規則 v3
# ============================================================
#
# 1. 如果 evidence_status = Yes：
#    - 有具體數據、年份、金額、百分比、認證、獎項、量化成果 → Clear
#    - 只有方向性描述或制度性描述，缺乏可驗證成果 → Not Clear
#    - 語氣很正面、很像 ESG 成果，但沒有具體證據 → Misleading
#
# 2. 如果 evidence_status = No 或 N/A：
#    - 通常 evidence_quality = N/A
#    - 但如果文本有強烈 ESG 口號式承諾、治理包裝、社會責任語氣，且缺乏證據 → Misleading 或 Not Clear
#
# 3. 不要因為文本有「2024 年」就自動判 Clear。
#    要看 2024 年是否連結到具體成果、數據、認證、活動或量化證據。
#
# 4. 不要因為文本很正式、很像永續報告就自動判 Clear。
#    如果沒有具體可驗證內容，應判 Not Clear 或 Misleading。
#
# 5. 如果文本有明確量化證據，例如「120 萬元」、

# %%
# ============================================================
# Hybrid Cell 13. Prompt v3 全 100 筆可續跑版
# Timeline Prompt v3 + Quality Prompt v3
# ============================================================

import os
import json
import time
from tqdm import tqdm
from openai import OpenAI
import os
from getpass import getpass

if "OPENAI_API_KEY" not in os.environ:
    api_key = getpass("請貼上你的 OpenAI API Key：").strip()
    os.environ["OPENAI_API_KEY"] = api_key

client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

GPT_MODEL = "gpt-4o"
GPT_TEMPERATURE = 0

print("✅ OpenAI client 已建立")
print("GPT_MODEL:", GPT_MODEL)
print("GPT_TEMPERATURE:", GPT_TEMPERATURE)
# ============================================================
# 13.1 設定進度儲存路徑
# ============================================================

TIMELINE_V3_PROGRESS_PATH = os.path.join(
    PROJECT_DIR,
    "gpt_timeline_v3_progress.json"
)

QUALITY_V3_PROGRESS_PATH = os.path.join(
    PROJECT_DIR,
    "gpt_quality_v3_progress.json"
)

print("TIMELINE_V3_PROGRESS_PATH:", TIMELINE_V3_PROGRESS_PATH)
print("QUALITY_V3_PROGRESS_PATH:", QUALITY_V3_PROGRESS_PATH)

# ============================================================
# 13.2 讀取既有進度
# ============================================================

if os.path.exists(TIMELINE_V3_PROGRESS_PATH):
    with open(TIMELINE_V3_PROGRESS_PATH, "r", encoding="utf-8") as f:
        timeline_v3_predictions = json.load(f)
    print("✅ 已讀取既有 timeline v3 預測進度：", len(timeline_v3_predictions))
else:
    timeline_v3_predictions = []
    print("尚無 timeline v3 進度，從 0 開始")

if os.path.exists(QUALITY_V3_PROGRESS_PATH):
    with open(QUALITY_V3_PROGRESS_PATH, "r", encoding="utf-8") as f:
        quality_v3_predictions = json.load(f)
    print("✅ 已讀取既有 quality v3 預測進度：", len(quality_v3_predictions))
else:
    quality_v3_predictions = []
    print("尚無 quality v3 進度，從 0 開始")

timeline_completed_ids = set([item["id"] for item in timeline_v3_predictions])
quality_completed_ids = set([item["id"] for item in quality_v3_predictions])

print("timeline 已完成 id 數量：", len(timeline_completed_ids))
print("quality 已完成 id 數量：", len(quality_completed_ids))
print("總 test_data 筆數：", len(test_data))

# ============================================================
# 13.3 單筆 Timeline v3 預測函數
# ============================================================

def gpt_predict_timeline_v3_full(test_item, top_k=TOP_K, max_retries=5):
    item_id = test_item["id"]
    test_text = get_text(test_item)

    retrieved_examples = retrieve_top_k_examples(test_text, top_k=top_k)
    roberta_pred = roberta_pred_by_id[item_id]

    prompt = build_timeline_prompt_v3(
        test_text=test_text,
        retrieved_examples=retrieved_examples,
        roberta_pred=roberta_pred
    )

    last_error = None

    for attempt in range(1, max_retries + 1):
        try:
            response = client.chat.completions.create(
                model=GPT_MODEL,
                messages=[
                    {
                        "role": "system",
                        "content": "你是一位嚴謹的 ESG Promise Verification 標註專家。你只能輸出合法 JSON。"
                    },
                    {
                        "role": "user",
                        "content": prompt
                    }
                ],
                temperature=GPT_TEMPERATURE
            )

            content = response.choices[0].message.content
            parsed = safe_parse_json(content)
            normalized = normalize_timeline_label(parsed)

            return {
                "id": item_id,
                "verification_timeline": normalized["verification_timeline"],
                "api_success": True,
                "error": None,
                "raw_response": content,
                "roberta_promise_status": roberta_pred["promise_status"],
                "roberta_evidence_status": roberta_pred["evidence_status"]
            }

        except Exception as e:
            last_error = str(e)
            print(f"id={item_id} Timeline v3 第 {attempt} 次失敗：{last_error}")

            wait_time = 10 * attempt
            print(f"等待 {wait_time} 秒後重試...")
            time.sleep(wait_time)

    return {
        "id": item_id,
        "verification_timeline": "N/A",
        "api_success": False,
        "error": last_error,
        "raw_response": None,
        "roberta_promise_status": roberta_pred_by_id[item_id]["promise_status"],
        "roberta_evidence_status": roberta_pred_by_id[item_id]["evidence_status"]
    }

# ============================================================
# 13.4 單筆 Quality v3 預測函數
# ============================================================

def gpt_predict_quality_v3_full(test_item, top_k=TOP_K, max_retries=5):
    item_id = test_item["id"]
    test_text = get_text(test_item)

    retrieved_examples = retrieve_top_k_examples(test_text, top_k=top_k)
    roberta_pred = roberta_pred_by_id[item_id]

    prompt = build_quality_prompt_v3(
        test_text=test_text,
        retrieved_examples=retrieved_examples,
        roberta_pred=roberta_pred
    )

    last_error = None

    for attempt in range(1, max_retries + 1):
        try:
            response = client.chat.completions.create(
                model=GPT_MODEL,
                messages=[
                    {
                        "role": "system",
                        "content": "你是一位嚴謹的 ESG Promise Verification 標註專家。你只能輸出合法 JSON。"
                    },
                    {
                        "role": "user",
                        "content": prompt
                    }
                ],
                temperature=GPT_TEMPERATURE
            )

            content = response.choices[0].message.content
            parsed = safe_parse_json(content)
            normalized = normalize_quality_label(parsed)

            return {
                "id": item_id,
                "evidence_quality": normalized["evidence_quality"],
                "api_success": True,
                "error": None,
                "raw_response": content,
                "roberta_promise_status": roberta_pred["promise_status"],
                "roberta_evidence_status": roberta_pred["evidence_status"]
            }

        except Exception as e:
            last_error = str(e)
            print(f"id={item_id} Quality v3 第 {attempt} 次失敗：{last_error}")

            wait_time = 10 * attempt
            print(f"等待 {wait_time} 秒後重試...")
            time.sleep(wait_time)

    return {
        "id": item_id,
        "evidence_quality": "N/A",
        "api_success": False,
        "error": last_error,
        "raw_response": None,
        "roberta_promise_status": roberta_pred_by_id[item_id]["promise_status"],
        "roberta_evidence_status": roberta_pred_by_id[item_id]["evidence_status"]
    }

# ============================================================
# 13.5 正式可續跑預測
# ============================================================

for idx, item in enumerate(tqdm(test_data, desc="Prompt v3 full predicting")):
    item_id = item["id"]

    print("\n" + "=" * 100)
    print(f"index {idx} | id {item_id}")

    # ------------------------------------------------------------
    # Timeline v3
    # ------------------------------------------------------------
    if item_id in timeline_completed_ids:
        print("Timeline v3 已完成，跳過")
    else:
        timeline_pred = gpt_predict_timeline_v3_full(item)
        timeline_v3_predictions.append(timeline_pred)
        timeline_completed_ids.add(item_id)

        with open(TIMELINE_V3_PROGRESS_PATH, "w", encoding="utf-8") as f:
            json.dump(timeline_v3_predictions, f, ensure_ascii=False, indent=2)

        print("[Timeline]")
        print("Gold:", item["verification_timeline"])
        print("Pred:", timeline_pred["verification_timeline"])
        print("API success:", timeline_pred["api_success"])

        time.sleep(3)

    # ------------------------------------------------------------
    # Quality v3
    # ------------------------------------------------------------
    if item_id in quality_completed_ids:
        print("Quality v3 已完成，跳過")
    else:
        quality_pred = gpt_predict_quality_v3_full(item)
        quality_v3_predictions.append(quality_pred)
        quality_completed_ids.add(item_id)

        with open(QUALITY_V3_PROGRESS_PATH, "w", encoding="utf-8") as f:
            json.dump(quality_v3_predictions, f, ensure_ascii=False, indent=2)

        print("[Evidence Quality]")
        print("Gold:", item["evidence_quality"])
        print("Pred:", quality_pred["evidence_quality"])
        print("API success:", quality_pred["api_success"])

        time.sleep(5)

    print(
        f"目前進度：Timeline {len(timeline_v3_predictions)}/{len(test_data)} | "
        f"Quality {len(quality_v3_predictions)}/{len(test_data)}"
    )

print("\n✅ Prompt v3 全部預測完成")
print("Timeline 預測筆數：", len(timeline_v3_predictions))
print("Timeline API success：", sum(1 for x in timeline_v3_predictions if x["api_success"]))
print("Timeline API failed：", sum(1 for x in timeline_v3_predictions if not x["api_success"]))

print("\nQuality 預測筆數：", len(quality_v3_predictions))
print("Quality API success：", sum(1 for x in quality_v3_predictions if x["api_success"]))
print("Quality API failed：", sum(1 for x in quality_v3_predictions if not x["api_success"]))

print("\n進度檔案：")
print("Timeline:", TIMELINE_V3_PROGRESS_PATH)
print("Quality :", QUALITY_V3_PROGRESS_PATH)
# Out:
# TIMELINE_V3_PROGRESS_PATH: /content/drive/MyDrive/ESG_Project/gpt_timeline_v3_progress.json
# QUALITY_V3_PROGRESS_PATH: /content/drive/MyDrive/ESG_Project/gpt_quality_v3_progress.json
# 尚無 timeline v3 進度，從 0 開始
# 尚無 quality v3 進度，從 0 開始
# timeline 已完成 id 數量： 0
# quality 已完成 id 數量： 0
# 總 test_data 筆數： 100
# Prompt v3 full predicting:   0%|          | 0/100 [00:00<?, ?it/s]
# ====================================================================================================
# index 0 | id 10939
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:   1%|          | 1/100 [00:10<16:30, 10.01s/it]
# 目前進度：Timeline 1/100 | Quality 1/100
#
# ====================================================================================================
# index 1 | id 10382
# [Timeline]
# Gold: longer_than_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:   2%|▏         | 2/100 [00:19<16:07,  9.87s/it]
# 目前進度：Timeline 2/100 | Quality 2/100
#
# ====================================================================================================
# index 2 | id 10450
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:   3%|▎         | 3/100 [00:29<16:06,  9.97s/it]
# 目前進度：Timeline 3/100 | Quality 3/100
#
# ====================================================================================================
# index 3 | id 10680
# [Timeline]
# Gold: N/A
# Pred: N/A
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:   4%|▍         | 4/100 [00:39<15:33,  9.72s/it]
# 目前進度：Timeline 4/100 | Quality 4/100
#
# ====================================================================================================
# index 4 | id 10373
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:   5%|▌         | 5/100 [00:48<15:12,  9.61s/it]
# 目前進度：Timeline 5/100 | Quality 5/100
#
# ====================================================================================================
# index 5 | id 10636
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:   6%|▌         | 6/100 [00:58<15:13,  9.72s/it]
# 目前進度：Timeline 6/100 | Quality 6/100
#
# ====================================================================================================
# index 6 | id 10795
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:   7%|▋         | 7/100 [01:08<15:11,  9.80s/it]
# 目前進度：Timeline 7/100 | Quality 7/100
#
# ====================================================================================================
# index 7 | id 10098
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:   8%|▊         | 8/100 [01:18<14:56,  9.74s/it]
# 目前進度：Timeline 8/100 | Quality 8/100
#
# ====================================================================================================
# index 8 | id 10072
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:   9%|▉         | 9/100 [01:27<14:49,  9.78s/it]
# 目前進度：Timeline 9/100 | Quality 9/100
#
# ====================================================================================================
# index 9 | id 10524
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  10%|█         | 10/100 [01:37<14:34,  9.72s/it]
# 目前進度：Timeline 10/100 | Quality 10/100
#
# ====================================================================================================
# index 10 | id 10176
# [Timeline]
# Gold: longer_than_5_years
# Pred: longer_than_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  11%|█         | 11/100 [01:47<14:30,  9.78s/it]
# 目前進度：Timeline 11/100 | Quality 11/100
#
# ====================================================================================================
# index 11 | id 10937
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  12%|█▏        | 12/100 [01:57<14:15,  9.72s/it]
# 目前進度：Timeline 12/100 | Quality 12/100
#
# ====================================================================================================
# index 12 | id 10329
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  13%|█▎        | 13/100 [02:06<14:04,  9.71s/it]
# 目前進度：Timeline 13/100 | Quality 13/100
#
# ====================================================================================================
# index 13 | id 10011
# [Timeline]
# Gold: already
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  14%|█▍        | 14/100 [02:16<13:58,  9.75s/it]
# 目前進度：Timeline 14/100 | Quality 14/100
#
# ====================================================================================================
# index 14 | id 10652
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  15%|█▌        | 15/100 [02:26<13:53,  9.81s/it]
# 目前進度：Timeline 15/100 | Quality 15/100
#
# ====================================================================================================
# index 15 | id 10578
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  16%|█▌        | 16/100 [02:35<13:34,  9.69s/it]
# 目前進度：Timeline 16/100 | Quality 16/100
#
# ====================================================================================================
# index 16 | id 10078
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  17%|█▋        | 17/100 [02:45<13:15,  9.58s/it]
# 目前進度：Timeline 17/100 | Quality 17/100
#
# ====================================================================================================
# index 17 | id 10825
# [Timeline]
# Gold: already
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  18%|█▊        | 18/100 [02:55<13:14,  9.69s/it]
# 目前進度：Timeline 18/100 | Quality 18/100
#
# ====================================================================================================
# index 18 | id 10041
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  19%|█▉        | 19/100 [03:07<14:02, 10.41s/it]
# 目前進度：Timeline 19/100 | Quality 19/100
#
# ====================================================================================================
# index 19 | id 10200
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  20%|██        | 20/100 [03:16<13:29, 10.12s/it]
# 目前進度：Timeline 20/100 | Quality 20/100
#
# ====================================================================================================
# index 20 | id 10597
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  21%|██        | 21/100 [03:26<13:01,  9.90s/it]
# 目前進度：Timeline 21/100 | Quality 21/100
#
# ====================================================================================================
# index 21 | id 10379
# [Timeline]
# Gold: already
# Pred: longer_than_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  22%|██▏       | 22/100 [03:35<12:40,  9.76s/it]
# 目前進度：Timeline 22/100 | Quality 22/100
#
# ====================================================================================================
# index 22 | id 10627
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  23%|██▎       | 23/100 [03:45<12:28,  9.72s/it]
# 目前進度：Timeline 23/100 | Quality 23/100
#
# ====================================================================================================
# index 23 | id 10065
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  24%|██▍       | 24/100 [03:54<12:18,  9.72s/it]
# 目前進度：Timeline 24/100 | Quality 24/100
#
# ====================================================================================================
# index 24 | id 10068
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  25%|██▌       | 25/100 [04:04<12:11,  9.76s/it]
# 目前進度：Timeline 25/100 | Quality 25/100
#
# ====================================================================================================
# index 25 | id 10872
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  26%|██▌       | 26/100 [04:14<12:06,  9.81s/it]
# 目前進度：Timeline 26/100 | Quality 26/100
#
# ====================================================================================================
# index 26 | id 10882
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  27%|██▋       | 27/100 [04:28<13:20, 10.96s/it]
# 目前進度：Timeline 27/100 | Quality 27/100
#
# ====================================================================================================
# index 27 | id 10170
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  28%|██▊       | 28/100 [04:37<12:38, 10.53s/it]
# 目前進度：Timeline 28/100 | Quality 28/100
#
# ====================================================================================================
# index 28 | id 10515
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  29%|██▉       | 29/100 [04:47<12:07, 10.24s/it]
# 目前進度：Timeline 29/100 | Quality 29/100
#
# ====================================================================================================
# index 29 | id 10544
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  30%|███       | 30/100 [04:57<11:51, 10.17s/it]
# 目前進度：Timeline 30/100 | Quality 30/100
#
# ====================================================================================================
# index 30 | id 10438
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  31%|███       | 31/100 [05:07<11:31, 10.02s/it]
# 目前進度：Timeline 31/100 | Quality 31/100
#
# ====================================================================================================
# index 31 | id 10739
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  32%|███▏      | 32/100 [05:18<11:39, 10.29s/it]
# 目前進度：Timeline 32/100 | Quality 32/100
#
# ====================================================================================================
# index 32 | id 10738
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  33%|███▎      | 33/100 [05:32<12:53, 11.55s/it]
# 目前進度：Timeline 33/100 | Quality 33/100
#
# ====================================================================================================
# index 33 | id 10516
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  34%|███▍      | 34/100 [05:42<12:07, 11.03s/it]
# 目前進度：Timeline 34/100 | Quality 34/100
#
# ====================================================================================================
# index 34 | id 10523
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  35%|███▌      | 35/100 [05:52<11:33, 10.67s/it]
# 目前進度：Timeline 35/100 | Quality 35/100
#
# ====================================================================================================
# index 35 | id 10201
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  36%|███▌      | 36/100 [06:12<14:33, 13.65s/it]
# 目前進度：Timeline 36/100 | Quality 36/100
#
# ====================================================================================================
# index 36 | id 10622
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  37%|███▋      | 37/100 [06:22<13:12, 12.58s/it]
# 目前進度：Timeline 37/100 | Quality 37/100
#
# ====================================================================================================
# index 37 | id 10955
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  38%|███▊      | 38/100 [06:34<12:43, 12.31s/it]
# 目前進度：Timeline 38/100 | Quality 38/100
#
# ====================================================================================================
# index 38 | id 10435
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  39%|███▉      | 39/100 [06:52<14:14, 14.00s/it]
# 目前進度：Timeline 39/100 | Quality 39/100
#
# ====================================================================================================
# index 39 | id 10868
# [Timeline]
# Gold: between_2_and_5_years
# Pred: within_2_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  40%|████      | 40/100 [07:02<12:40, 12.68s/it]
# 目前進度：Timeline 40/100 | Quality 40/100
#
# ====================================================================================================
# index 40 | id 10160
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  41%|████      | 41/100 [07:17<13:09, 13.39s/it]
# 目前進度：Timeline 41/100 | Quality 41/100
#
# ====================================================================================================
# index 41 | id 10889
# [Timeline]
# Gold: already
# Pred: longer_than_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  42%|████▏     | 42/100 [07:26<11:47, 12.19s/it]
# 目前進度：Timeline 42/100 | Quality 42/100
#
# ====================================================================================================
# index 42 | id 10599
# [Timeline]
# Gold: longer_than_5_years
# Pred: longer_than_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  43%|████▎     | 43/100 [07:37<11:14, 11.83s/it]
# 目前進度：Timeline 43/100 | Quality 43/100
#
# ====================================================================================================
# index 43 | id 10790
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  44%|████▍     | 44/100 [07:48<10:42, 11.47s/it]
# 目前進度：Timeline 44/100 | Quality 44/100
#
# ====================================================================================================
# index 44 | id 10384
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  45%|████▌     | 45/100 [08:07<12:42, 13.86s/it]
# 目前進度：Timeline 45/100 | Quality 45/100
#
# ====================================================================================================
# index 45 | id 10509
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  46%|████▌     | 46/100 [08:17<11:28, 12.75s/it]
# 目前進度：Timeline 46/100 | Quality 46/100
#
# ====================================================================================================
# index 46 | id 10679
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  47%|████▋     | 47/100 [08:32<11:50, 13.40s/it]
# 目前進度：Timeline 47/100 | Quality 47/100
#
# ====================================================================================================
# index 47 | id 10056
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  48%|████▊     | 48/100 [08:42<10:36, 12.24s/it]
# 目前進度：Timeline 48/100 | Quality 48/100
#
# ====================================================================================================
# index 48 | id 10547
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  49%|████▉     | 49/100 [08:55<10:46, 12.68s/it]
# 目前進度：Timeline 49/100 | Quality 49/100
#
# ====================================================================================================
# index 49 | id 10624
# [Timeline]
# Gold: N/A
# Pred: N/A
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  50%|█████     | 50/100 [09:05<09:47, 11.74s/it]
# 目前進度：Timeline 50/100 | Quality 50/100
#
# ====================================================================================================
# index 50 | id 10017
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Misleading
# Pred: Misleading
# API success: True
# Prompt v3 full predicting:  51%|█████     | 51/100 [09:14<09:00, 11.03s/it]
# 目前進度：Timeline 51/100 | Quality 51/100
#
# ====================================================================================================
# index 51 | id 10268
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  52%|█████▏    | 52/100 [09:27<09:11, 11.49s/it]
# 目前進度：Timeline 52/100 | Quality 52/100
#
# ====================================================================================================
# index 52 | id 10211
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  53%|█████▎    | 53/100 [09:37<08:42, 11.11s/it]
# 目前進度：Timeline 53/100 | Quality 53/100
#
# ====================================================================================================
# index 53 | id 10528
# [Timeline]
# Gold: already
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  54%|█████▍    | 54/100 [09:49<08:34, 11.19s/it]
# 目前進度：Timeline 54/100 | Quality 54/100
#
# ====================================================================================================
# index 54 | id 10826
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  55%|█████▌    | 55/100 [10:00<08:24, 11.21s/it]
# 目前進度：Timeline 55/100 | Quality 55/100
#
# ====================================================================================================
# index 55 | id 10664
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  56%|█████▌    | 56/100 [10:14<08:49, 12.03s/it]
# 目前進度：Timeline 56/100 | Quality 56/100
#
# ====================================================================================================
# index 56 | id 10543
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  57%|█████▋    | 57/100 [10:29<09:13, 12.88s/it]
# 目前進度：Timeline 57/100 | Quality 57/100
#
# ====================================================================================================
# index 57 | id 10262
# [Timeline]
# Gold: already
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  58%|█████▊    | 58/100 [10:38<08:19, 11.89s/it]
# 目前進度：Timeline 58/100 | Quality 58/100
#
# ====================================================================================================
# index 58 | id 10900
# [Timeline]
# Gold: already
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  59%|█████▉    | 59/100 [10:48<07:41, 11.26s/it]
# 目前進度：Timeline 59/100 | Quality 59/100
#
# ====================================================================================================
# index 59 | id 10874
# [Timeline]
# Gold: already
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  60%|██████    | 60/100 [10:59<07:26, 11.17s/it]
# 目前進度：Timeline 60/100 | Quality 60/100
#
# ====================================================================================================
# index 60 | id 10903
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  61%|██████    | 61/100 [11:14<08:03, 12.39s/it]
# 目前進度：Timeline 61/100 | Quality 61/100
#
# ====================================================================================================
# index 61 | id 10580
# [Timeline]
# Gold: already
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  62%|██████▏   | 62/100 [11:25<07:38, 12.06s/it]
# 目前進度：Timeline 62/100 | Quality 62/100
#
# ====================================================================================================
# index 62 | id 10897
# [Timeline]
# Gold: N/A
# Pred: N/A
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  63%|██████▎   | 63/100 [11:40<07:50, 12.72s/it]
# 目前進度：Timeline 63/100 | Quality 63/100
#
# ====================================================================================================
# index 63 | id 10712
# [Timeline]
# Gold: already
# Pred: N/A
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  64%|██████▍   | 64/100 [11:49<07:04, 11.79s/it]
# 目前進度：Timeline 64/100 | Quality 64/100
#
# ====================================================================================================
# index 64 | id 10069
# [Timeline]
# Gold: N/A
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  65%|██████▌   | 65/100 [12:00<06:44, 11.56s/it]
# 目前進度：Timeline 65/100 | Quality 65/100
#
# ====================================================================================================
# index 65 | id 10210
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  66%|██████▌   | 66/100 [12:10<06:17, 11.10s/it]
# 目前進度：Timeline 66/100 | Quality 66/100
#
# ====================================================================================================
# index 66 | id 10976
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  67%|██████▋   | 67/100 [12:20<05:52, 10.68s/it]
# 目前進度：Timeline 67/100 | Quality 67/100
#
# ====================================================================================================
# index 67 | id 10427
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  68%|██████▊   | 68/100 [12:34<06:14, 11.70s/it]
# 目前進度：Timeline 68/100 | Quality 68/100
#
# ====================================================================================================
# index 68 | id 10367
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  69%|██████▉   | 69/100 [12:44<05:42, 11.05s/it]
# 目前進度：Timeline 69/100 | Quality 69/100
#
# ====================================================================================================
# index 69 | id 10572
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  70%|███████   | 70/100 [12:53<05:19, 10.64s/it]
# 目前進度：Timeline 70/100 | Quality 70/100
#
# ====================================================================================================
# index 70 | id 10455
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  71%|███████   | 71/100 [13:09<05:55, 12.26s/it]
# 目前進度：Timeline 71/100 | Quality 71/100
#
# ====================================================================================================
# index 71 | id 10090
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  72%|███████▏  | 72/100 [13:21<05:33, 11.92s/it]
# 目前進度：Timeline 72/100 | Quality 72/100
#
# ====================================================================================================
# index 72 | id 10541
# [Timeline]
# Gold: N/A
# Pred: N/A
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  73%|███████▎  | 73/100 [13:35<05:42, 12.69s/it]
# 目前進度：Timeline 73/100 | Quality 73/100
#
# ====================================================================================================
# index 73 | id 10518
# [Timeline]
# Gold: already
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  74%|███████▍  | 74/100 [13:46<05:14, 12.08s/it]
# 目前進度：Timeline 74/100 | Quality 74/100
#
# ====================================================================================================
# index 74 | id 10025
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  75%|███████▌  | 75/100 [13:56<04:46, 11.47s/it]
# 目前進度：Timeline 75/100 | Quality 75/100
#
# ====================================================================================================
# index 75 | id 10487
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  76%|███████▌  | 76/100 [14:05<04:21, 10.90s/it]
# 目前進度：Timeline 76/100 | Quality 76/100
#
# ====================================================================================================
# index 76 | id 10061
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  77%|███████▋  | 77/100 [14:15<04:02, 10.56s/it]
# 目前進度：Timeline 77/100 | Quality 77/100
#
# ====================================================================================================
# index 77 | id 10109
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  78%|███████▊  | 78/100 [14:25<03:45, 10.25s/it]
# 目前進度：Timeline 78/100 | Quality 78/100
#
# ====================================================================================================
# index 78 | id 10354
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  79%|███████▉  | 79/100 [14:34<03:31, 10.07s/it]
# 目前進度：Timeline 79/100 | Quality 79/100
#
# ====================================================================================================
# index 79 | id 10717
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  80%|████████  | 80/100 [14:44<03:17,  9.90s/it]
# 目前進度：Timeline 80/100 | Quality 80/100
#
# ====================================================================================================
# index 80 | id 10709
# [Timeline]
# Gold: longer_than_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  81%|████████  | 81/100 [14:53<03:05,  9.77s/it]
# 目前進度：Timeline 81/100 | Quality 81/100
#
# ====================================================================================================
# index 81 | id 10346
# [Timeline]
# Gold: within_2_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  82%|████████▏ | 82/100 [15:06<03:12, 10.72s/it]
# 目前進度：Timeline 82/100 | Quality 82/100
#
# ====================================================================================================
# index 82 | id 10251
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  83%|████████▎ | 83/100 [15:16<02:58, 10.50s/it]
# 目前進度：Timeline 83/100 | Quality 83/100
#
# ====================================================================================================
# index 83 | id 10451
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  84%|████████▍ | 84/100 [15:26<02:44, 10.27s/it]
# 目前進度：Timeline 84/100 | Quality 84/100
#
# ====================================================================================================
# index 84 | id 10827
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  85%|████████▌ | 85/100 [15:35<02:30, 10.06s/it]
# 目前進度：Timeline 85/100 | Quality 85/100
#
# ====================================================================================================
# index 85 | id 10742
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  86%|████████▌ | 86/100 [15:46<02:24, 10.33s/it]
# 目前進度：Timeline 86/100 | Quality 86/100
#
# ====================================================================================================
# index 86 | id 10032
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  87%|████████▋ | 87/100 [15:58<02:19, 10.74s/it]
# 目前進度：Timeline 87/100 | Quality 87/100
#
# ====================================================================================================
# index 87 | id 10915
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  88%|████████▊ | 88/100 [16:19<02:45, 13.81s/it]
# 目前進度：Timeline 88/100 | Quality 88/100
#
# ====================================================================================================
# index 88 | id 10637
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  89%|████████▉ | 89/100 [16:29<02:20, 12.75s/it]
# 目前進度：Timeline 89/100 | Quality 89/100
#
# ====================================================================================================
# index 89 | id 10884
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  90%|█████████ | 90/100 [16:39<01:59, 11.92s/it]
# 目前進度：Timeline 90/100 | Quality 90/100
#
# ====================================================================================================
# index 90 | id 10651
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  91%|█████████ | 91/100 [16:49<01:40, 11.12s/it]
# 目前進度：Timeline 91/100 | Quality 91/100
#
# ====================================================================================================
# index 91 | id 10605
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  92%|█████████▏| 92/100 [17:04<01:40, 12.55s/it]
# 目前進度：Timeline 92/100 | Quality 92/100
#
# ====================================================================================================
# index 92 | id 10470
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  93%|█████████▎| 93/100 [17:14<01:21, 11.69s/it]
# 目前進度：Timeline 93/100 | Quality 93/100
#
# ====================================================================================================
# index 93 | id 10812
# [Timeline]
# Gold: between_2_and_5_years
# Pred: between_2_and_5_years
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  94%|█████████▍| 94/100 [17:24<01:07, 11.20s/it]
# 目前進度：Timeline 94/100 | Quality 94/100
#
# ====================================================================================================
# index 94 | id 10320
# [Timeline]
# Gold: between_2_and_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Not Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting:  95%|█████████▌| 95/100 [17:35<00:55, 11.06s/it]
# 目前進度：Timeline 95/100 | Quality 95/100
#
# ====================================================================================================
# index 95 | id 10696
# [Timeline]
# Gold: longer_than_5_years
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  96%|█████████▌| 96/100 [17:44<00:42, 10.50s/it]
# 目前進度：Timeline 96/100 | Quality 96/100
#
# ====================================================================================================
# index 96 | id 10799
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: N/A
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  97%|█████████▋| 97/100 [17:58<00:34, 11.64s/it]
# 目前進度：Timeline 97/100 | Quality 97/100
#
# ====================================================================================================
# index 97 | id 10311
# [Timeline]
# Gold: already
# Pred: already
# API success: True
# [Evidence Quality]
# Gold: Clear
# Pred: Clear
# API success: True
# Prompt v3 full predicting:  98%|█████████▊| 98/100 [18:09<00:22, 11.31s/it]
# 目前進度：Timeline 98/100 | Quality 98/100
#
# ====================================================================================================
# index 98 | id 10722
# id=10722 Timeline v3 第 1 次失敗：Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 等待 10 秒後重試...
# [Timeline]
# Gold: N/A
# Pred: already
# API success: True
# id=10722 Quality v3 第 1 次失敗：Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 等待 10 秒後重試...
# [Evidence Quality]
# Gold: N/A
# Pred: N/A
# API success: True
# Prompt v3 full predicting:  99%|█████████▉| 99/100 [18:44<00:18, 18.45s/it]
# 目前進度：Timeline 99/100 | Quality 99/100
#
# ====================================================================================================
# index 99 | id 10560
# [Timeline]
# Gold: longer_than_5_years
# Pred: N/A
# API success: True
# id=10560 Quality v3 第 1 次失敗：Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 等待 10 秒後重試...
# id=10560 Quality v3 第 2 次失敗：Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 等待 20 秒後重試...
# id=10560 Quality v3 第 3 次失敗：Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 等待 30 秒後重試...
# id=10560 Quality v3 第 4 次失敗：Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# 等待 40 秒後重試...
# [Evidence Quality]
# Gold: Clear
# Pred: Not Clear
# API success: True
# Prompt v3 full predicting: 100%|██████████| 100/100 [20:45<00:00, 12.45s/it]
# 目前進度：Timeline 100/100 | Quality 100/100
#
# ✅ Prompt v3 全部預測完成
# Timeline 預測筆數： 100
# Timeline API success： 100
# Timeline API failed： 0
#
# Quality 預測筆數： 100
# Quality API success： 100
# Quality API failed： 0
#
# 進度檔案：
# Timeline: /content/drive/MyDrive/ESG_Project/gpt_timeline_v3_progress.json
# Quality : /content/drive/MyDrive/ESG_Project/gpt_quality_v3_progress.json

# %%
# ============================================================
# Hybrid Cell 16. Timeline Postprocess v4
# 不呼叫 GPT，只修正 GPT Timeline Prompt v3 的 already 過度預測
# ============================================================

import re
import pandas as pd
from sklearn.metrics import classification_report, f1_score, accuracy_score

# ============================================================
# 16.1 Timeline 後處理規則
# ============================================================

def timeline_postprocess_v4(item, pred_vt):
    """
    修正 GPT Timeline Prompt v3 的常見錯誤：
    1. longer_than_5_years 被誤判成 already
    2. N/A 被誤判成 already
    3. between_2_and_5_years 被誤判成 already
    """
    text = clean_text(get_text(item))
    item_id = item["id"]

    # ------------------------------------------------------------
    # A. 明確長期目標 / 長期承諾
    # ------------------------------------------------------------
    long_term_patterns = [
        "2050",
        "2040",
        "2035",
        "2030",
        "淨零",
        "碳中和",
        "長期目標",
        "中長期目標",
        "短中長期目標",
        "短、中、長期目標",
        "長期策略",
        "長期減碳",
        "多年計畫",
        "8 年",
        "八年",
        "五年以上",
        "超過五年",
        "50 多年",
        "五十多年"
    ]

    if any(k in text for k in long_term_patterns):
        # 但「長期合作」「長年推動」若明顯是過去已發生成果，不一定是 longer_than_5_years
        past_activity_clues = [
            "2024 年共",
            "2024年共",
            "共捐助",
            "贊助",
            "捐助",
            "已累積",
            "累積",
            "自 2017 年起",
            "自 2018 年起",
            "自 2021 年起",
            "活動",
            "賽事"
        ]

        if not any(k in text for k in past_activity_clues):
            return "longer_than_5_years"

    # ------------------------------------------------------------
    # B. 明確 N/A 類：風險表、背景描述、課程/架構/委員會/評鑑流程
    # ------------------------------------------------------------
    na_patterns = [
        "風險報告",
        "全球風險報告",
        "風險管理概論",
        "風險管理框架",
        "新興風險識別",
        "評鑑小組",
        "年度評鑑",
        "審計委員會",
        "董事會制訂",
        "委員會成員",
        "生命週期角度檢視",
        "背景下",
        "依據 ENCORE",
        "生物多樣性熱點影響分析",
        "熱區",
        "不適用",
        "自身營運",
        "負面新聞 / 訴訟",
        "裁罰風險",
        "課程內容涵蓋",
        "培訓課程",
        "組織架構",
        "管理架構",
        "治理架構"
    ]

    if any(k in text for k in na_patterns):
        return "N/A"

    # 如果 RoBERTa 預測 promise_status = No 且 evidence_status = N/A，timeline 通常不適用
    roberta_pred = roberta_pred_by_id[item_id]
    if roberta_pred["promise_status"] == "No" and roberta_pred["evidence_status"] == "N/A":
        # 但如果文本明確有長期目標，前面已經先處理
        return "N/A"

    # ------------------------------------------------------------
    # C. 中期承諾 / 後續推動
    # ------------------------------------------------------------
    mid_term_patterns = [
        "將持續",
        "後續追蹤",
        "持續追蹤",
        "持續改善",
        "持續優化",
        "持續精進",
        "逐步建立",
        "逐步推動",
        "規劃",
        "計畫與",
        "建構",
        "未來將",
        "期待",
        "期盼",
        "共同推動",
        "共同努力",
        "強化",
        "促進人才",
        "擴展高潛力",
        "培育",
        "建立永續夥伴關係",
        "因應減碳",
        "永續潮流",
        "法定報告",
        "揭露永續相關資訊"
    ]

    if any(k in text for k in mid_term_patterns):
        # 若有 2030/2050 等，應該給 longer_than_5_years，已在 A 處理
        return "between_2_and_5_years"

    # ------------------------------------------------------------
    # D. 明確 already 類：具體過去成果 / 活動 / 數據
    # ------------------------------------------------------------
    already_patterns = [
        "已完成",
        "已取得",
        "已通過",
        "已達成",
        "已執行",
        "已設立",
        "2024 年共",
        "2024年共",
        "共捐助",
        "共投入",
        "累計",
        "已累積",
        "贊助",
        "捐助",
        "獲頒",
        "完成訓練",
        "每季召開",
        "通過考試",
        "取得認證",
        "通過認證",
        "導入 ISO",
        "ISO 45001",
        "ISO 27001",
        "ISO 14064"
    ]

    if any(k in text for k in already_patterns):
        return "already"

    # ------------------------------------------------------------
    # E. 其他：保留 GPT 原本預測
    # ------------------------------------------------------------
    return pred_vt


# ============================================================
# 16.2 套用 postprocess 到全部 test_data
# ============================================================

timeline_v4_predictions = []

for item in test_data:
    item_id = item["id"]
    pred_vt_before = timeline_v3_pred_by_id[item_id]["verification_timeline"]
    pred_vt_after = timeline_postprocess_v4(item, pred_vt_before)

    timeline_v4_predictions.append({
        "id": item_id,
        "verification_timeline": pred_vt_after,
        "before_verification_timeline": pred_vt_before
    })

timeline_v4_pred_by_id = {
    item["id"]: item
    for item in timeline_v4_predictions
}

print("timeline_v4_predictions 筆數：", len(timeline_v4_predictions))

# ============================================================
# 16.3 評估 v3 before / v4 after
# ============================================================

labels_vt = LABEL_LISTS_ALL["verification_timeline"]

y_true_vt = [item["verification_timeline"] for item in test_data]

y_pred_vt_v3 = [
    timeline_v3_pred_by_id[item["id"]]["verification_timeline"]
    for item in test_data
]

y_pred_vt_v4 = [
    timeline_v4_pred_by_id[item["id"]]["verification_timeline"]
    for item in test_data
]

print("\n" + "=" * 90)
print("Timeline v3 Before Postprocess")
print("=" * 90)

v3_macro = f1_score(
    y_true_vt,
    y_pred_vt_v3,
    labels=labels_vt,
    average="macro",
    zero_division=0
)
v3_acc = accuracy_score(y_true_vt, y_pred_vt_v3)

print("v3 Macro F1:", v3_macro)
print("v3 Accuracy:", v3_acc)

print("\n" + "=" * 90)
print("Timeline v4 After Postprocess")
print("=" * 90)

print(classification_report(
    y_true_vt,
    y_pred_vt_v4,
    labels=labels_vt,
    zero_division=0
))

vt_v4_macro_f1 = f1_score(
    y_true_vt,
    y_pred_vt_v4,
    labels=labels_vt,
    average="macro",
    zero_division=0
)

vt_v4_micro_f1 = f1_score(
    y_true_vt,
    y_pred_vt_v4,
    labels=labels_vt,
    average="micro",
    zero_division=0
)

vt_v4_acc = accuracy_score(y_true_vt, y_pred_vt_v4)

print(f"v4 Macro F1: {vt_v4_macro_f1:.4f}")
print(f"v4 Micro F1: {vt_v4_micro_f1:.4f}")
print(f"v4 Accuracy: {vt_v4_acc:.4f}")

# ============================================================
# 16.4 查看被修改案例
# ============================================================

changed_rows = []

for item in test_data:
    item_id = item["id"]
    before = timeline_v3_pred_by_id[item_id]["verification_timeline"]
    after = timeline_v4_pred_by_id[item_id]["verification_timeline"]

    if before != after:
        changed_rows.append({
            "id": item_id,
            "gold_vt": item["verification_timeline"],
            "before_vt": before,
            "after_vt": after,
            "before_correct": item["verification_timeline"] == before,
            "after_correct": item["verification_timeline"] == after,
            "text": get_text(item)[:300]
        })

changed_timeline_v4_df = pd.DataFrame(changed_rows)

print("\n被 postprocess 修改的案例數：", len(changed_timeline_v4_df))
display(changed_timeline_v4_df.head(60))

# ============================================================
# 16.5 錯誤案例數比較
# ============================================================

before_errors = sum(
    1 for item in test_data
    if item["verification_timeline"] != timeline_v3_pred_by_id[item["id"]]["verification_timeline"]
)

after_errors = sum(
    1 for item in test_data
    if item["verification_timeline"] != timeline_v4_pred_by_id[item["id"]]["verification_timeline"]
)

print("\n錯誤數比較：")
print("Before errors:", before_errors)
print("After errors :", after_errors)
print("改善筆數：", before_errors - after_errors)
# Out:
# timeline_v4_predictions 筆數： 100
#
# ==========================================================================================
# Timeline v3 Before Postprocess
# ==========================================================================================
# v3 Macro F1: 0.3335382813643683
# v3 Accuracy: 0.49
#
# ==========================================================================================
# Timeline v4 After Postprocess
# ==========================================================================================
#                        precision    recall  f1-score   support
#
#               already       0.59      0.45      0.51        38
#        within_2_years       0.00      0.00      0.00         1
# between_2_and_5_years       0.57      0.77      0.66        26
#   longer_than_5_years       0.50      0.28      0.36        18
#                   N/A       0.58      0.88      0.70        17
#
#              accuracy                           0.57       100
#             macro avg       0.45      0.48      0.44       100
#          weighted avg       0.56      0.57      0.55       100
#
# v4 Macro F1: 0.4436
# v4 Micro F1: 0.5700
# v4 Accuracy: 0.5700
#
# 被 postprocess 修改的案例數： 41
#        id                gold_vt              before_vt  \
# 0   10382    longer_than_5_years  between_2_and_5_years
# 1   10450                already                already
# 2   10373  between_2_and_5_years                already
# 3   10098  between_2_and_5_years                already
# 4   10524    longer_than_5_years                already
# 5   10652  between_2_and_5_years                already
# 6   10825                already  between_2_and_5_years
# 7   10041                already                already
# 8   10200                already                already
# 9   10597  between_2_and_5_years  between_2_and_5_years
# 10  10068                    N/A                already
# 11  10872                already                already
# 12  10515                    N/A                already
# 13  10544                already                already
# 14  10438                already                already
# 15  10523  between_2_and_5_years                already
# 16  10201                    N/A                already
# 17  10622                already                already
# 18  10868  between_2_and_5_years         within_2_years
# 19  10160    longer_than_5_years                already
# 20  10790                    N/A                already
# 21  10056  between_2_and_5_years  between_2_and_5_years
# 22  10547                already                already
# 23  10017  between_2_and_5_years                already
# 24  10268                already                already
# 25  10528                already  between_2_and_5_years
# 26  10826                    N/A                already
# 27  10664  between_2_and_5_years  between_2_and_5_years
# 28  10069                    N/A  between_2_and_5_years
# 29  10455  between_2_and_5_years                already
# 30  10109                    N/A                already
# 31  10354                    N/A                already
# 32  10709    longer_than_5_years  between_2_and_5_years
# 33  10827                    N/A                already
# 34  10032                already                already
# 35  10915    longer_than_5_years                already
# 36  10605                    N/A                already
# 37  10320  between_2_and_5_years                already
# 38  10696    longer_than_5_years                already
# 39  10799                    N/A                already
# 40  10722                    N/A                already
#
#                  after_vt  before_correct  after_correct  \
# 0     longer_than_5_years           False           True
# 1   between_2_and_5_years            True          False
# 2   between_2_and_5_years           False           True
# 3   between_2_and_5_years           False           True
# 4   between_2_and_5_years           False          False
# 5                     N/A           False          False
# 6                     N/A           False          False
# 7   between_2_and_5_years            True          False
# 8                     N/A            True          False
# 9                     N/A            True          False
# 10                    N/A           False           True
# 11  between_2_and_5_years            True          False
# 12                    N/A           False           True
# 13                    N/A            True          False
# 14  between_2_and_5_years            True          False
# 15  between_2_and_5_years           False           True
# 16                    N/A           False           True
# 17                    N/A            True          False
# 18  between_2_and_5_years           False           True
# 19                    N/A           False          False
# 20                    N/A           False           True
# 21    longer_than_5_years            True          False
# 22  between_2_and_5_years            True          False
# 23  between_2_and_5_years           False           True
# 24                    N/A            True          False
# 25    longer_than_5_years           False          False
# 26                    N/A           False           True
# 27    longer_than_5_years            True          False
# 28                    N/A           False           True
# 29  between_2_and_5_years           False           True
# 30                    N/A           False           True
# 31                    N/A           False           True
# 32    longer_than_5_years           False           True
# 33                    N/A           False           True
# 34  between_2_and_5_years            True          False
# 35                    N/A           False          False
# 36                    N/A           False           True
# 37  between_2_and_5_years           False           True
# 38    longer_than_5_years           False           True
# 39  between_2_and_5_years           False          False
# 40                    N/A           False           True
#
#                                                  text
# 0   以核心機會的成熟度結果為基礎，規劃具體可行的行動方案。根據各行動方案的重要性與實施複雜度進行...
# 1   此外，鼓勵本土優秀跑者挑戰佳績，持續設置「破全國紀錄獎金」、響應政策公私協力攜手推廣識詐及阻...
# 2   過去四年，AI 為全世界帶來巨大的改變，時至今日依然還在持續演進中，相信在人類的進步史中 A...
# 3   台積公司以聯合國開發計劃署提出的「勞工權利、環境權利、表達與參與、性別平等、服務與產品責任、...
# 4   因應網路新興科技世代（含 5G、大數據、AI、物聯網、雲端／虛擬／容器化技術）帶動的數位轉型...
# 5   本公司除持續維持 ISO 27001 資安認證之有效性外，並採用美國國家標準與技術研究所的網...
# 6   國巨身為全球被動元件產業的領導者，朝以成為永續企業為願景，以環境友善、卓越運營、社會共融作為...
# 7   2024 年基隆陽明貨櫃場安全實績    協議組織  - 每季召開。  - 協議安全衛生管理...
# 8   聯電在 2003 年成立「企業資訊安全委員會」，由總經理擔任主席，並由數位功能組織吳宗賢資深...
# 9   永續供應鏈管理架構涵蓋永續規範、供應商評鑑、風險識別與管理機制等面向，並透過與供應商攜手合作...
# 10  各作業內容針對物理性、化學性、人因性、生物性、其他危害等有暴露或可能暴露危害之勞工，以及特別...
# 11  為持續提升公司競爭力與員工專業發展，依據 EMC 訓練體系，2024年度訓練以「強化職能發展...
# 12  經檢視本集團生物多樣性熱點影響分析結果，銀行營運據點方圓 1 公里範圍皆未與生物多樣性熱區等...
# 13  台積公司與國內外多所大學密切合作，投入涵蓋先進半導體材料、元件、製程、設備、封裝技術、綠色製...
# 14  「道德行為準則」訓練為全員必修課程，公司既有及新進員工100%完成訓練，並通過考試。運用案例...
# 15  為因應全球市場變動趨勢，快速回應客戶需求，同時促進人才多元化、擴展高潛力員工國際視野及培育國...
# 16  和碩審計委員會於2013年成立，依法由全體獨立董事組成，並依相關法令由董事會制訂「審計委員會...
# 17  健全的治理架構及有效的董事會是公司治理的良好基石，使管理階層能夠充分掌握公司經營策略及營運績...
# 18  隨著全球對於企業永續發展議題的重視，永續報導的趨勢已由自願性的永續報告書走向強制的法定報告，...
# 19  緯創為確保原物料不使用有害物質，符合國際環保法規及客戶有害物質規定，依循 IECQ QC08...
# 20  | 自身營運 | 2. 氣候自然法規趨嚴<br>6. 負面新聞 / 訴訟<br>7. 裁罰風...
# 21  台泥旗下達和航運所有水泥船皆優先自主導入岸電系統，優於IMO規定  達和航運積極響應國際海事...
# 22  本公司全體內勤正職同仁皆定期接受年度績效檢視，全員年度績效考核均設有連結金融消費者保護及公平...
# 23  統一企業致力於穩健經營，確保公司財務穩定與持續成長，並兼顧股東權益、員工發展與社會責任。我們...
# 24  在當今全球面臨氣候變遷和環境挑戰的背景下，我們深刻認識到企業在推動永續發展中的重要角色。緯創...
# 25  中華電信自 2022 年與農業部林業及自然保育署合作 8 年 15 萬棵造林計畫,攜手中華電...
# 26  根據世界經濟論壇 2025 全球風險報告，隨著地緣政治、環境、社會、經濟和技術領域緊張局勢的...
# 27  持續以能源流 - 碳流 - 物質流 - 成本之耦合分析，精進碳中和路徑。持續進行低碳新興煉鋼...
# 28  透過選擇有機農業或永續農業生產的食材，以及優化供應鏈以減少能源消耗和運輸成本，航空業能能夠有...
# 29  在建立永續夥伴關係方面，計畫與全台各地教育局與學校密切合作，並建構線上Q&A、共備資源平台，...
# 30  每年則由評鑑小組對主要合格供應商進行年度評鑑，評鑑小組成員包括品保、生產、技術、材發、採購等...
# 31  依據 ENCORE (Exploring Natural Capital Opportuni...
# 32  光寶 50 多年來提供產品廣泛應用於雲端運算、汽車電子、光電、LED 照明、智慧醫療、資通訊...
# 33  11 月 11~29 日期間捐書人數 39 位，總計捐贈 90 本書籍。依陽光社會福利基金中...
# 34  2024 年度，瑞昱半導體與瑞昱職工福利委員會提撥超過新台幣 1 億 1,390 萬元之經費...
# 35  本公司由隸屬於董事會之永續經營委員會作為推動誠信經營之專責單位，以董事長為主任委員，並由全體...
# 36  藥華醫藥從生命週期角度檢視廢棄物產出、清除、處理及回收等流程，詳盡記錄投入物質與廢棄物產出量...
# 37  因應減碳、永續潮流, 金融監督管理委員會規範年報須依循國際財務報導準則 (IFRS) 揭露永...
# 38  本集團自 2016 年起導入 ISO 14064-1 溫室氣體盤查，並於 2019 年起擴大...
# 39  為協助非華語系外籍員工克服語言障礙，日月光半導體高雄廠自 2022 年起與學校合作辦理華語課...
# 40  課程內容涵蓋多個面向，包含風險管理概論、風險管理框架建構及應用、新興風險識別，以及結合各職能...
# 錯誤數比較：
# Before errors: 51
# After errors : 43
# 改善筆數： 8

# %%
# ============================================================
# Hybrid Cell 17. 合併 Hybrid v4 並計算官方加權分數
# Task 1 promise_status        = RoBERTa
# Task 2 verification_timeline = GPT Timeline v3 + Postprocess v4
# Task 3 evidence_status       = RoBERTa
# Task 4 evidence_quality      = GPT Quality Prompt v3
# ============================================================

import os
import json
import pandas as pd
from sklearn.metrics import classification_report, f1_score, accuracy_score

# ============================================================
# 17.1 建立 prediction by id
# ============================================================

roberta_pred_by_id = {
    item["id"]: item
    for item in roberta_predictions
}

timeline_v4_pred_by_id = {
    item["id"]: item
    for item in timeline_v4_predictions
}

quality_v3_pred_by_id = {
    item["id"]: item
    for item in quality_v3_predictions
}

# 檢查缺漏
missing_roberta = [
    item["id"] for item in test_data
    if item["id"] not in roberta_pred_by_id
]

missing_timeline_v4 = [
    item["id"] for item in test_data
    if item["id"] not in timeline_v4_pred_by_id
]

missing_quality_v3 = [
    item["id"] for item in test_data
    if item["id"] not in quality_v3_pred_by_id
]

print("missing_roberta:", missing_roberta)
print("missing_timeline_v4:", missing_timeline_v4)
print("missing_quality_v3:", missing_quality_v3)

if missing_roberta or missing_timeline_v4 or missing_quality_v3:
    raise ValueError("有任務缺少預測，請先補齊。")

# ============================================================
# 17.2 合併四任務預測
# ============================================================

hybrid_v4_predictions = []

for item in test_data:
    item_id = item["id"]

    pred = {
        "id": item_id,
        "promise_status": roberta_pred_by_id[item_id]["promise_status"],
        "verification_timeline": timeline_v4_pred_by_id[item_id]["verification_timeline"],
        "evidence_status": roberta_pred_by_id[item_id]["evidence_status"],
        "evidence_quality": quality_v3_pred_by_id[item_id]["evidence_quality"]
    }

    hybrid_v4_predictions.append(pred)

print("hybrid_v4_predictions 筆數：", len(hybrid_v4_predictions))
print("第一筆 hybrid_v4 prediction:")
print(hybrid_v4_predictions[0])

hybrid_v4_pred_by_id = {
    item["id"]: item
    for item in hybrid_v4_predictions
}

# ============================================================
# 17.3 評估四個任務
# ============================================================

hybrid_v4_eval_results = {}

for field in ALL_FIELDS:
    y_true = [
        item[field]
        for item in test_data
    ]

    y_pred = [
        hybrid_v4_pred_by_id[item["id"]][field]
        for item in test_data
    ]

    labels = LABEL_LISTS_ALL[field]

    print("\n" + "=" * 90)
    print(f"Hybrid v4 Evaluation: {field}")
    print("=" * 90)

    print(classification_report(
        y_true,
        y_pred,
        labels=labels,
        zero_division=0
    ))

    macro_f1 = f1_score(
        y_true,
        y_pred,
        labels=labels,
        average="macro",
        zero_division=0
    )

    micro_f1 = f1_score(
        y_true,
        y_pred,
        labels=labels,
        average="micro",
        zero_division=0
    )

    acc = accuracy_score(y_true, y_pred)

    hybrid_v4_eval_results[field] = {
        "macro_f1": macro_f1,
        "micro_f1": micro_f1,
        "accuracy": acc
    }

    print(f"Macro F1: {macro_f1:.4f}")
    print(f"Micro F1: {micro_f1:.4f}")
    print(f"Accuracy: {acc:.4f}")

# ============================================================
# 17.4 官方加權總分
# ============================================================

official_score_v4 = (
    hybrid_v4_eval_results["promise_status"]["macro_f1"] * OFFICIAL_WEIGHTS["promise_status"]
    + hybrid_v4_eval_results["evidence_status"]["macro_f1"] * OFFICIAL_WEIGHTS["evidence_status"]
    + hybrid_v4_eval_results["evidence_quality"]["macro_f1"] * OFFICIAL_WEIGHTS["evidence_quality"]
    + hybrid_v4_eval_results["verification_timeline"]["macro_f1"] * OFFICIAL_WEIGHTS["verification_timeline"]
)

print("\n" + "=" * 90)
print("Hybrid v4 Official Weighted Score")
print("=" * 90)

print("promise_status Macro F1:", hybrid_v4_eval_results["promise_status"]["macro_f1"])
print("verification_timeline Macro F1:", hybrid_v4_eval_results["verification_timeline"]["macro_f1"])
print("evidence_status Macro F1:", hybrid_v4_eval_results["evidence_status"]["macro_f1"])
print("evidence_quality Macro F1:", hybrid_v4_eval_results["evidence_quality"]["macro_f1"])

print("\nOfficial Weighted Score v4:", official_score_v4)

# ============================================================
# 17.5 與 v2 / v3 比較
# ============================================================

print("\n" + "=" * 90)
print("Hybrid Score Comparison")
print("=" * 90)

try:
    print("Hybrid v2 Official Score:", official_score)
except:
    print("Hybrid v2 Official Score: 找不到 official_score 變數")

try:
    print("Hybrid v3 Official Score:", official_score_v3)
except:
    print("Hybrid v3 Official Score: 找不到 official_score_v3 變數")

print("Hybrid v4 Official Score:", official_score_v4)

# ============================================================
# 17.6 儲存 Hybrid v4 結果
# ============================================================

HYBRID_V4_EVAL_PATH = os.path.join(
    PROJECT_DIR,
    "hybrid_v4_eval_results.json"
)

HYBRID_V4_PRED_PATH = os.path.join(
    PROJECT_DIR,
    "hybrid_v4_predictions.json"
)

save_obj = {
    "method": "Hybrid v4: RoBERTa Task1/3 + GPT Timeline v3 + Timeline Postprocess v4 + GPT Quality v3",
    "official_weights": OFFICIAL_WEIGHTS,
    "hybrid_predictions": hybrid_v4_predictions,
    "hybrid_eval_results": hybrid_v4_eval_results,
    "official_score": official_score_v4,
    "paths": {
        "timeline_v3_progress_path": TIMELINE_V3_PROGRESS_PATH,
        "quality_v3_progress_path": QUALITY_V3_PROGRESS_PATH
    }
}

with open(HYBRID_V4_EVAL_PATH, "w", encoding="utf-8") as f:
    json.dump(save_obj, f, ensure_ascii=False, indent=2)

with open(HYBRID_V4_PRED_PATH, "w", encoding="utf-8") as f:
    json.dump(hybrid_v4_predictions, f, ensure_ascii=False, indent=2)

print("\n✅ 已儲存 Hybrid v4 評估結果：", HYBRID_V4_EVAL_PATH)
print("✅ 已儲存 Hybrid v4 預測結果：", HYBRID_V4_PRED_PATH)

# ============================================================
# 17.7 Misleading 樣本檢查
# ============================================================

print("\n" + "=" * 90)
print("Misleading 樣本檢查")
print("=" * 90)

for item in test_data:
    if item.get("evidence_quality") == "Misleading":
        item_id = item["id"]
        pred = hybrid_v4_pred_by_id[item_id]

        print("id:", item_id)
        print("Gold verification_timeline:", item["verification_timeline"])
        print("Pred verification_timeline:", pred["verification_timeline"])
        print("Gold evidence_quality:", item["evidence_quality"])
        print("Pred evidence_quality:", pred["evidence_quality"])
        print("Gold promise_status:", item["promise_status"])
        print("Pred promise_status:", pred["promise_status"])
        print("Gold evidence_status:", item["evidence_status"])
        print("Pred evidence_status:", pred["evidence_status"])
        print("text:", get_text(item))
# Out:
# missing_roberta: []
# missing_timeline_v4: []
# missing_quality_v3: []
# hybrid_v4_predictions 筆數： 100
# 第一筆 hybrid_v4 prediction:
# {'id': 10939, 'promise_status': 'Yes', 'verification_timeline': 'already', 'evidence_status': 'Yes', 'evidence_quality': 'Clear'}
#
# ==========================================================================================
# Hybrid v4 Evaluation: promise_status
# ==========================================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.93      0.93      0.93        83
#           No       0.65      0.65      0.65        17
#
#     accuracy                           0.88       100
#    macro avg       0.79      0.79      0.79       100
# weighted avg       0.88      0.88      0.88       100
#
# Macro F1: 0.7874
# Micro F1: 0.8800
# Accuracy: 0.8800
#
# ==========================================================================================
# Hybrid v4 Evaluation: verification_timeline
# ==========================================================================================
#                        precision    recall  f1-score   support
#
#               already       0.59      0.45      0.51        38
#        within_2_years       0.00      0.00      0.00         1
# between_2_and_5_years       0.57      0.77      0.66        26
#   longer_than_5_years       0.50      0.28      0.36        18
#                   N/A       0.58      0.88      0.70        17
#
#              accuracy                           0.57       100
#             macro avg       0.45      0.48      0.44       100
#          weighted avg       0.56      0.57      0.55       100
#
# Macro F1: 0.4436
# Micro F1: 0.5700
# Accuracy: 0.5700
#
# ==========================================================================================
# Hybrid v4 Evaluation: evidence_status
# ==========================================================================================
#               precision    recall  f1-score   support
#
#          Yes       0.85      0.91      0.88        67
#           No       0.64      0.44      0.52        16
#          N/A       0.76      0.76      0.76        17
#
#     accuracy                           0.81       100
#    macro avg       0.75      0.70      0.72       100
# weighted avg       0.80      0.81      0.80       100
#
# Macro F1: 0.7203
# Micro F1: 0.8100
# Accuracy: 0.8100
#
# ==========================================================================================
# Hybrid v4 Evaluation: evidence_quality
# ==========================================================================================
#               precision    recall  f1-score   support
#
#        Clear       0.78      0.64      0.70        55
#    Not Clear       0.18      0.64      0.28        11
#   Misleading       1.00      1.00      1.00         1
#          N/A       0.93      0.42      0.58        33
#
#     accuracy                           0.57       100
#    macro avg       0.72      0.67      0.64       100
# weighted avg       0.77      0.57      0.62       100
#
# Macro F1: 0.6408
# Micro F1: 0.5700
# Accuracy: 0.5700
#
# ==========================================================================================
# Hybrid v4 Official Weighted Score
# ==========================================================================================
# promise_status Macro F1: 0.7873848334514528
# verification_timeline Macro F1: 0.443603533446541
# evidence_status Macro F1: 0.7203074141993594
# evidence_quality Macro F1: 0.6408333333333334
#
# Official Weighted Score v4: 0.6644013876337461
#
# ==========================================================================================
# Hybrid Score Comparison
# ==========================================================================================
# Hybrid v2 Official Score: 找不到 official_score 變數
# Hybrid v3 Official Score: 0.6478915998214202
# Hybrid v4 Official Score: 0.6644013876337461
#
# ✅ 已儲存 Hybrid v4 評估結果： /content/drive/MyDrive/ESG_Project/hybrid_v4_eval_results.json
# ✅ 已儲存 Hybrid v4 預測結果： /content/drive/MyDrive/ESG_Project/hybrid_v4_predictions.json
#
# ==========================================================================================
# Misleading 樣本檢查
# ==========================================================================================
# id: 10017
# Gold verification_timeline: between_2_and_5_years
# Pred verification_timeline: between_2_and_5_years
# Gold evidence_quality: Misleading
# Pred evidence_quality: Misleading
# Gold promise_status: Yes
# Pred promise_status: Yes
# Gold evidence_status: Yes
# Pred evidence_status: Yes
# text: 統一企業致力於穩健經營，確保公司財務穩定與持續成長，並兼顧股東權益、員工發展與社會責任。我們透過創新產品與服務、多元化營運布局及強化供應鏈韌性，提升企業競爭力，並承諾遵循財務與稅務法規，維持高標準的財務透明度與公司治理。
